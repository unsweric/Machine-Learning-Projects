# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile 
import math

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 4
sample_id = 1235
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 4:
# Samples: 10000
# Label Counts: {0: 1003, 1: 963, 2: 1041, 3: 976, 4: 1004, 5: 1021, 6: 1004, 7: 981, 8: 1024, 9: 983}
# First 20 Labels: [0, 6, 0, 2, 7, 2, 1, 2, 4, 1, 5, 6, 6, 3, 1, 3, 5, 5, 8, 1]
#
# Example of Image 1235:
# Image - Min Value: 5 Max Value: 239
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_min = x.min(axis=(1, 2), keepdims=True)
    x_max = x.max(axis=(1, 2), keepdims=True)
    x = (x - x_min)/(x_max-x_min)
    return x
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    from sklearn import preprocessing
    lb = preprocessing.LabelBinarizer()
    encoding_map = range(10)
    lb.fit(encoding_map)
    x=lb.transform(x)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shape_x=[None, image_shape[0], image_shape[1], image_shape[2]]
    x1=tf.placeholder(tf.float32,shape_x,name='x')
    return x1


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    shape_y=[None, n_classes]
    y1=tf.placeholder(tf.float32,shape_y,name='y')
    return y1


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob1=tf.placeholder(tf.float32,name='keep_prob')
    return keep_prob1


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %% [markdown]
# The recent paper above suggests, specifically for ReLUs, to initialize all biases to 0 and to randomly set the weights of a layer using the same std = sqrt(2/n) with n being the number of inputs of the layer (n = kernel_width*kernel_height*depth_previous_layer). This was a game-changer for me.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight=tf.Variable(tf.truncated_normal([*conv_ksize,x_tensor.get_shape().as_list()[3],conv_num_outputs], mean=0, stddev=math.sqrt(2/(conv_ksize[0]*conv_ksize[1]*x_tensor.get_shape().as_list()[3]*conv_num_outputs))))
    bias=tf.Variable(tf.zeros(shape=conv_num_outputs))
    conv=tf.nn.conv2d(x_tensor,weight,strides=[1,*conv_strides,1],padding='SAME')
    conv=tf.nn.bias_add(conv,bias)
    conv=tf.nn.relu(conv)
    conv=tf.nn.max_pool(conv,ksize=[1,*pool_ksize,1],strides=[1,*pool_strides,1],padding='SAME')
    return conv


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    fla=tf.contrib.layers.flatten(x_tensor)
    return fla


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight=tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1],num_outputs], mean=0, stddev=math.sqrt(2/(x_tensor.get_shape().as_list()[1]*num_outputs))))
    bias=tf.Variable(tf.zeros(shape=num_outputs))
    ful=tf.add(tf.matmul(x_tensor,weight),bias)
    ful=tf.nn.relu(ful)
    #ful=tf.nn.dropout(ful,neural_net_keep_prob_input())
    return ful


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight=tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1],num_outputs], mean=0, stddev=math.sqrt(2/(x_tensor.get_shape().as_list()[1]*num_outputs))))
    bias=tf.Variable(tf.zeros(shape=num_outputs))
    out=tf.add(tf.matmul(x_tensor,weight),bias)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %% [markdown]
# To decide how to build your structure and select hyperparameters, it seems to be common practice to use filters of size 3x3 and stride of 1 in the convolutional layers, to max-pool every one or two convolutional layer with filter size 2x2 and stride 2, to use dropout layers on slightly oversized layers and to use around two fully-connected layers at the end. Additionally, it was recommended to me to “use increasing depth of the convolutional layers (for example, double the number of filters each time: 32, 64, 128).” And for the fully connected layers, to “use decreasing number of hidden units (for example, 512, 256, and 128), this might help reach the 80% validation accuracy.” You can find a lot of VERY useful insights on building convolutional nets in here29

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv=conv2d_maxpool(x, 32, (3,3), (1,1), (2,2), (2,2))
    conv=conv2d_maxpool(conv, 64, (3,3), (1,1), (2,2), (2,2))
    conv=conv2d_maxpool(conv, 128, (3,3), (1,1), (2,2), (2,2))
    conv=tf.nn.dropout(conv,keep_prob)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    fla=flatten(conv)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    ful=fully_conn(fla, 512)
    ful=tf.nn.dropout(ful,keep_prob)
    ful=fully_conn(ful, 256)
    ful=tf.nn.dropout(ful,keep_prob)
    ful=fully_conn(ful, 128)
    ful=tf.nn.dropout(ful,keep_prob)
    
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out=output(ful, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    
    #logits = conv_net(x, keep_prob)
    #logits = tf.identity(logits, name='logits')
    #cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
    #optimizer=optimizer.minimize(cost)
    
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_train, label_train, feature_valid, label_valid,cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    # Loss and Optimizer
    
    loss_train = session.run(cost, feed_dict={
                x: feature_train,
                y: label_train,
                keep_prob: 1.})
    acc_train = session.run(accuracy, feed_dict={
                x: feature_train,
                y: label_train,
                keep_prob: 1.})
    loss_valid = session.run(cost, feed_dict={
                x: feature_valid,
                y: label_valid,
                keep_prob: 1.})
    acc_valid = session.run(accuracy, feed_dict={
                x: feature_valid,
                y: label_valid,
                keep_prob: 1.})
    
    print( 'Loss_train: {:>10.4f} Accuracy_train: {:.6f} Loss_valid: {:>10.4f} Accuracy_valid: {:.6f}'.format(loss_train,acc_train,loss_valid,acc_valid))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.92

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    #optimizer = tf.train.AdamOptimizer()
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels,valid_features, valid_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss_train:     2.3035 Accuracy_train: 0.075000 Loss_valid:     2.3026 Accuracy_valid: 0.099800
# Epoch  2, CIFAR-10 Batch 1:  Loss_train:     2.2879 Accuracy_train: 0.100000 Loss_valid:     2.2681 Accuracy_valid: 0.130800
# Epoch  3, CIFAR-10 Batch 1:  Loss_train:     2.1567 Accuracy_train: 0.225000 Loss_valid:     2.1221 Accuracy_valid: 0.164800
# Epoch  4, CIFAR-10 Batch 1:  Loss_train:     2.1557 Accuracy_train: 0.150000 Loss_valid:     2.0723 Accuracy_valid: 0.190400
# Epoch  5, CIFAR-10 Batch 1:  Loss_train:     2.1978 Accuracy_train: 0.225000 Loss_valid:     2.1444 Accuracy_valid: 0.205600
# Epoch  6, CIFAR-10 Batch 1:  Loss_train:     2.0318 Accuracy_train: 0.275000 Loss_valid:     1.9696 Accuracy_valid: 0.246200
# Epoch  7, CIFAR-10 Batch 1:  Loss_train:     1.9105 Accuracy_train: 0.275000 Loss_valid:     1.8946 Accuracy_valid: 0.287600
# Epoch  8, CIFAR-10 Batch 1:  Loss_train:     1.8947 Accuracy_train: 0.350000 Loss_valid:     1.8005 Accuracy_valid: 0.310000
# Epoch  9, CIFAR-10 Batch 1:  Loss_train:     1.8558 Accuracy_train: 0.350000 Loss_valid:     1.7675 Accuracy_valid: 0.316400
# Epoch 10, CIFAR-10 Batch 1:  Loss_train:     1.8009 Accuracy_train: 0.350000 Loss_valid:     1.7213 Accuracy_valid: 0.342600
# Epoch 11, CIFAR-10 Batch 1:  Loss_train:     1.7296 Accuracy_train: 0.375000 Loss_valid:     1.6711 Accuracy_valid: 0.362400
# Epoch 12, CIFAR-10 Batch 1:  Loss_train:     1.6682 Accuracy_train: 0.450000 Loss_valid:     1.6522 Accuracy_valid: 0.372400
# Epoch 13, CIFAR-10 Batch 1:  Loss_train:     1.6137 Accuracy_train: 0.400000 Loss_valid:     1.6252 Accuracy_valid: 0.382800
# Epoch 14, CIFAR-10 Batch 1:  Loss_train:     1.5110 Accuracy_train: 0.425000 Loss_valid:     1.5797 Accuracy_valid: 0.398000
# Epoch 15, CIFAR-10 Batch 1:  Loss_train:     1.4064 Accuracy_train: 0.500000 Loss_valid:     1.5375 Accuracy_valid: 0.420400
# Epoch 16, CIFAR-10 Batch 1:  Loss_train:     1.3453 Accuracy_train: 0.450000 Loss_valid:     1.5038 Accuracy_valid: 0.435000
# Epoch 17, CIFAR-10 Batch 1:  Loss_train:     1.2630 Accuracy_train: 0.525000 Loss_valid:     1.4890 Accuracy_valid: 0.445600
# Epoch 18, CIFAR-10 Batch 1:  Loss_train:     1.1426 Accuracy_train: 0.575000 Loss_valid:     1.4440 Accuracy_valid: 0.469000
# Epoch 19, CIFAR-10 Batch 1:  Loss_train:     1.0919 Accuracy_train: 0.575000 Loss_valid:     1.4181 Accuracy_valid: 0.485400
# Epoch 20, CIFAR-10 Batch 1:  Loss_train:     1.0200 Accuracy_train: 0.575000 Loss_valid:     1.4052 Accuracy_valid: 0.493600
# Epoch 21, CIFAR-10 Batch 1:  Loss_train:     0.9627 Accuracy_train: 0.650000 Loss_valid:     1.4041 Accuracy_valid: 0.490400
# Epoch 22, CIFAR-10 Batch 1:  Loss_train:     0.8431 Accuracy_train: 0.750000 Loss_valid:     1.3400 Accuracy_valid: 0.511600
# Epoch 23, CIFAR-10 Batch 1:  Loss_train:     0.7877 Accuracy_train: 0.725000 Loss_valid:     1.3462 Accuracy_valid: 0.517200
# Epoch 24, CIFAR-10 Batch 1:  Loss_train:     0.7033 Accuracy_train: 0.800000 Loss_valid:     1.3195 Accuracy_valid: 0.528200
# Epoch 25, CIFAR-10 Batch 1:  Loss_train:     0.6613 Accuracy_train: 0.775000 Loss_valid:     1.3272 Accuracy_valid: 0.531600
# Epoch 26, CIFAR-10 Batch 1:  Loss_train:     0.6435 Accuracy_train: 0.850000 Loss_valid:     1.3122 Accuracy_valid: 0.535800
# Epoch 27, CIFAR-10 Batch 1:  Loss_train:     0.5651 Accuracy_train: 0.900000 Loss_valid:     1.3186 Accuracy_valid: 0.541200
# Epoch 28, CIFAR-10 Batch 1:  Loss_train:     0.5452 Accuracy_train: 0.925000 Loss_valid:     1.2983 Accuracy_valid: 0.548600
# Epoch 29, CIFAR-10 Batch 1:  Loss_train:     0.5531 Accuracy_train: 0.900000 Loss_valid:     1.2749 Accuracy_valid: 0.556800
# Epoch 30, CIFAR-10 Batch 1:  Loss_train:     0.5098 Accuracy_train: 0.900000 Loss_valid:     1.2393 Accuracy_valid: 0.566800
# Epoch 31, CIFAR-10 Batch 1:  Loss_train:     0.5425 Accuracy_train: 0.850000 Loss_valid:     1.3161 Accuracy_valid: 0.547400
# Epoch 32, CIFAR-10 Batch 1:  Loss_train:     0.4509 Accuracy_train: 0.850000 Loss_valid:     1.2916 Accuracy_valid: 0.561800
# Epoch 33, CIFAR-10 Batch 1:  Loss_train:     0.4296 Accuracy_train: 0.900000 Loss_valid:     1.3668 Accuracy_valid: 0.556200
# Epoch 34, CIFAR-10 Batch 1:  Loss_train:     0.3769 Accuracy_train: 0.900000 Loss_valid:     1.3075 Accuracy_valid: 0.571000
# Epoch 35, CIFAR-10 Batch 1:  Loss_train:     0.3259 Accuracy_train: 0.925000 Loss_valid:     1.3039 Accuracy_valid: 0.576400
# Epoch 36, CIFAR-10 Batch 1:  Loss_train:     0.2908 Accuracy_train: 0.925000 Loss_valid:     1.3151 Accuracy_valid: 0.578800
# Epoch 37, CIFAR-10 Batch 1:  Loss_train:     0.2449 Accuracy_train: 0.975000 Loss_valid:     1.2844 Accuracy_valid: 0.588200
# Epoch 38, CIFAR-10 Batch 1:  Loss_train:     0.2347 Accuracy_train: 0.975000 Loss_valid:     1.4130 Accuracy_valid: 0.568200
# Epoch 39, CIFAR-10 Batch 1:  Loss_train:     0.1981 Accuracy_train: 0.950000 Loss_valid:     1.3987 Accuracy_valid: 0.579000
# Epoch 40, CIFAR-10 Batch 1:  Loss_train:     0.1723 Accuracy_train: 0.975000 Loss_valid:     1.3900 Accuracy_valid: 0.572800
# Epoch 41, CIFAR-10 Batch 1:  Loss_train:     0.1705 Accuracy_train: 1.000000 Loss_valid:     1.3065 Accuracy_valid: 0.594400
# Epoch 42, CIFAR-10 Batch 1:  Loss_train:     0.1871 Accuracy_train: 1.000000 Loss_valid:     1.2710 Accuracy_valid: 0.586800
# Epoch 43, CIFAR-10 Batch 1:  Loss_train:     0.2092 Accuracy_train: 1.000000 Loss_valid:     1.3684 Accuracy_valid: 0.556200
# Epoch 44, CIFAR-10 Batch 1:  Loss_train:     0.1381 Accuracy_train: 1.000000 Loss_valid:     1.5049 Accuracy_valid: 0.536200
# Epoch 45, CIFAR-10 Batch 1:  Loss_train:     0.1078 Accuracy_train: 1.000000 Loss_valid:     1.4713 Accuracy_valid: 0.567600
# Epoch 46, CIFAR-10 Batch 1:  Loss_train:     0.1535 Accuracy_train: 1.000000 Loss_valid:     1.4738 Accuracy_valid: 0.543400
# Epoch 47, CIFAR-10 Batch 1:  Loss_train:     0.1148 Accuracy_train: 1.000000 Loss_valid:     1.3843 Accuracy_valid: 0.585200
# Epoch 48, CIFAR-10 Batch 1:  Loss_train:     0.0879 Accuracy_train: 1.000000 Loss_valid:     1.4099 Accuracy_valid: 0.599600
# Epoch 49, CIFAR-10 Batch 1:  Loss_train:     0.0888 Accuracy_train: 0.975000 Loss_valid:     1.4380 Accuracy_valid: 0.596000
# Epoch 50, CIFAR-10 Batch 1:  Loss_train:     0.0556 Accuracy_train: 1.000000 Loss_valid:     1.4304 Accuracy_valid: 0.607600
# Epoch 51, CIFAR-10 Batch 1:  Loss_train:     0.0495 Accuracy_train: 1.000000 Loss_valid:     1.5895 Accuracy_valid: 0.588600
# Epoch 52, CIFAR-10 Batch 1:  Loss_train:     0.0575 Accuracy_train: 1.000000 Loss_valid:     1.7425 Accuracy_valid: 0.576200
# Epoch 53, CIFAR-10 Batch 1:  Loss_train:     0.0568 Accuracy_train: 1.000000 Loss_valid:     1.7063 Accuracy_valid: 0.573600
# Epoch 54, CIFAR-10 Batch 1:  Loss_train:     0.0407 Accuracy_train: 1.000000 Loss_valid:     1.6830 Accuracy_valid: 0.579400
# Epoch 55, CIFAR-10 Batch 1:  Loss_train:     0.0477 Accuracy_train: 1.000000 Loss_valid:     1.8479 Accuracy_valid: 0.556200
# Epoch 56, CIFAR-10 Batch 1:  Loss_train:     0.0287 Accuracy_train: 1.000000 Loss_valid:     1.5192 Accuracy_valid: 0.607400
# Epoch 57, CIFAR-10 Batch 1:  Loss_train:     0.0217 Accuracy_train: 1.000000 Loss_valid:     1.5802 Accuracy_valid: 0.603800
# Epoch 58, CIFAR-10 Batch 1:  Loss_train:     0.0243 Accuracy_train: 1.000000 Loss_valid:     1.6362 Accuracy_valid: 0.595600
# Epoch 59, CIFAR-10 Batch 1:  Loss_train:     0.0178 Accuracy_train: 1.000000 Loss_valid:     1.6609 Accuracy_valid: 0.595200
# Epoch 60, CIFAR-10 Batch 1:  Loss_train:     0.0153 Accuracy_train: 1.000000 Loss_valid:     1.7209 Accuracy_valid: 0.591800
# Epoch 61, CIFAR-10 Batch 1:  Loss_train:     0.0103 Accuracy_train: 1.000000 Loss_valid:     1.7923 Accuracy_valid: 0.583000
# Epoch 62, CIFAR-10 Batch 1:  Loss_train:     0.0252 Accuracy_train: 1.000000 Loss_valid:     1.8713 Accuracy_valid: 0.574600
# Epoch 63, CIFAR-10 Batch 1:  Loss_train:     0.0156 Accuracy_train: 1.000000 Loss_valid:     1.7788 Accuracy_valid: 0.584400
# Epoch 64, CIFAR-10 Batch 1:  Loss_train:     0.0121 Accuracy_train: 1.000000 Loss_valid:     1.9171 Accuracy_valid: 0.584600
# Epoch 65, CIFAR-10 Batch 1:  Loss_train:     0.0065 Accuracy_train: 1.000000 Loss_valid:     2.0556 Accuracy_valid: 0.576000
# Epoch 66, CIFAR-10 Batch 1:  Loss_train:     0.0081 Accuracy_train: 1.000000 Loss_valid:     1.9069 Accuracy_valid: 0.594000
# Epoch 67, CIFAR-10 Batch 1:  Loss_train:     0.0084 Accuracy_train: 1.000000 Loss_valid:     1.9246 Accuracy_valid: 0.582000
# Epoch 68, CIFAR-10 Batch 1:  Loss_train:     0.0148 Accuracy_train: 1.000000 Loss_valid:     2.1337 Accuracy_valid: 0.557800
# Epoch 69, CIFAR-10 Batch 1:  Loss_train:     0.0093 Accuracy_train: 1.000000 Loss_valid:     2.0405 Accuracy_valid: 0.571800
# Epoch 70, CIFAR-10 Batch 1:  Loss_train:     0.0048 Accuracy_train: 1.000000 Loss_valid:     1.9205 Accuracy_valid: 0.586600
# Epoch 71, CIFAR-10 Batch 1:  Loss_train:     0.0069 Accuracy_train: 1.000000 Loss_valid:     1.9111 Accuracy_valid: 0.585600
# Epoch 72, CIFAR-10 Batch 1:  Loss_train:     0.0091 Accuracy_train: 1.000000 Loss_valid:     1.9207 Accuracy_valid: 0.602400
# Epoch 73, CIFAR-10 Batch 1:  Loss_train:     0.0244 Accuracy_train: 1.000000 Loss_valid:     2.0593 Accuracy_valid: 0.568600
# Epoch 74, CIFAR-10 Batch 1:  Loss_train:     0.0057 Accuracy_train: 1.000000 Loss_valid:     2.0968 Accuracy_valid: 0.586600
# Epoch 75, CIFAR-10 Batch 1:  Loss_train:     0.0057 Accuracy_train: 1.000000 Loss_valid:     2.2148 Accuracy_valid: 0.582800
# Epoch 76, CIFAR-10 Batch 1:  Loss_train:     0.0039 Accuracy_train: 1.000000 Loss_valid:     2.2650 Accuracy_valid: 0.574200
# Epoch 77, CIFAR-10 Batch 1:  Loss_train:     0.0040 Accuracy_train: 1.000000 Loss_valid:     2.2336 Accuracy_valid: 0.575600
# Epoch 78, CIFAR-10 Batch 1:  Loss_train:     0.0022 Accuracy_train: 1.000000 Loss_valid:     2.0607 Accuracy_valid: 0.592400
# Epoch 79, CIFAR-10 Batch 1:  Loss_train:     0.0019 Accuracy_train: 1.000000 Loss_valid:     1.9647 Accuracy_valid: 0.599400
# Epoch 80, CIFAR-10 Batch 1:  Loss_train:     0.0025 Accuracy_train: 1.000000 Loss_valid:     2.1855 Accuracy_valid: 0.583800
# Epoch 81, CIFAR-10 Batch 1:  Loss_train:     0.0017 Accuracy_train: 1.000000 Loss_valid:     2.1414 Accuracy_valid: 0.595600
# Epoch 82, CIFAR-10 Batch 1:  Loss_train:     0.0024 Accuracy_train: 1.000000 Loss_valid:     2.1351 Accuracy_valid: 0.594400
# Epoch 83, CIFAR-10 Batch 1:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     2.2561 Accuracy_valid: 0.585400
# Epoch 84, CIFAR-10 Batch 1:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     2.1853 Accuracy_valid: 0.592800
# Epoch 85, CIFAR-10 Batch 1:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     2.3288 Accuracy_valid: 0.590800
# Epoch 86, CIFAR-10 Batch 1:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     2.2753 Accuracy_valid: 0.598400
# Epoch 87, CIFAR-10 Batch 1:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     2.3503 Accuracy_valid: 0.606800
# Epoch 88, CIFAR-10 Batch 1:  Loss_train:     0.0009 Accuracy_train: 1.000000 Loss_valid:     2.3047 Accuracy_valid: 0.601400
# Epoch 89, CIFAR-10 Batch 1:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     2.2743 Accuracy_valid: 0.601800
# Epoch 90, CIFAR-10 Batch 1:  Loss_train:     0.0036 Accuracy_train: 1.000000 Loss_valid:     2.3706 Accuracy_valid: 0.582600
# Epoch 91, CIFAR-10 Batch 1:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     2.3658 Accuracy_valid: 0.580200
# Epoch 92, CIFAR-10 Batch 1:  Loss_train:     0.0043 Accuracy_train: 1.000000 Loss_valid:     2.5102 Accuracy_valid: 0.564400
# Epoch 93, CIFAR-10 Batch 1:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     2.4363 Accuracy_valid: 0.579200
# Epoch 94, CIFAR-10 Batch 1:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     2.2228 Accuracy_valid: 0.595400
# Epoch 95, CIFAR-10 Batch 1:  Loss_train:     0.0011 Accuracy_train: 1.000000 Loss_valid:     2.1965 Accuracy_valid: 0.602200
# Epoch 96, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     2.3532 Accuracy_valid: 0.607000
# Epoch 97, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     2.4197 Accuracy_valid: 0.608400
# Epoch 98, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     2.4538 Accuracy_valid: 0.608400
# Epoch 99, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     2.4690 Accuracy_valid: 0.614600
# Epoch 100, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     2.5585 Accuracy_valid: 0.612000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels,valid_features, valid_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss_train:     2.3033 Accuracy_train: 0.075000 Loss_valid:     2.3026 Accuracy_valid: 0.099800
# Epoch  1, CIFAR-10 Batch 2:  Loss_train:     2.2830 Accuracy_train: 0.200000 Loss_valid:     2.2661 Accuracy_valid: 0.138200
# Epoch  1, CIFAR-10 Batch 3:  Loss_train:     2.0235 Accuracy_train: 0.200000 Loss_valid:     2.1314 Accuracy_valid: 0.175000
# Epoch  1, CIFAR-10 Batch 4:  Loss_train:     1.9730 Accuracy_train: 0.200000 Loss_valid:     2.0657 Accuracy_valid: 0.196200
# Epoch  1, CIFAR-10 Batch 5:  Loss_train:     1.9232 Accuracy_train: 0.225000 Loss_valid:     1.9078 Accuracy_valid: 0.257600
# Epoch  2, CIFAR-10 Batch 1:  Loss_train:     2.0780 Accuracy_train: 0.250000 Loss_valid:     1.8290 Accuracy_valid: 0.293000
# Epoch  2, CIFAR-10 Batch 2:  Loss_train:     1.8845 Accuracy_train: 0.325000 Loss_valid:     1.7441 Accuracy_valid: 0.332000
# Epoch  2, CIFAR-10 Batch 3:  Loss_train:     1.6114 Accuracy_train: 0.350000 Loss_valid:     1.7442 Accuracy_valid: 0.334000
# Epoch  2, CIFAR-10 Batch 4:  Loss_train:     1.6788 Accuracy_train: 0.300000 Loss_valid:     1.6501 Accuracy_valid: 0.381800
# Epoch  2, CIFAR-10 Batch 5:  Loss_train:     1.7054 Accuracy_train: 0.350000 Loss_valid:     1.6411 Accuracy_valid: 0.388600
# Epoch  3, CIFAR-10 Batch 1:  Loss_train:     1.8178 Accuracy_train: 0.300000 Loss_valid:     1.5870 Accuracy_valid: 0.399200
# Epoch  3, CIFAR-10 Batch 2:  Loss_train:     1.5705 Accuracy_train: 0.500000 Loss_valid:     1.5227 Accuracy_valid: 0.419200
# Epoch  3, CIFAR-10 Batch 3:  Loss_train:     1.3166 Accuracy_train: 0.500000 Loss_valid:     1.5077 Accuracy_valid: 0.436400
# Epoch  3, CIFAR-10 Batch 4:  Loss_train:     1.4923 Accuracy_train: 0.425000 Loss_valid:     1.4920 Accuracy_valid: 0.439800
# Epoch  3, CIFAR-10 Batch 5:  Loss_train:     1.4437 Accuracy_train: 0.450000 Loss_valid:     1.4335 Accuracy_valid: 0.464400
# Epoch  4, CIFAR-10 Batch 1:  Loss_train:     1.4920 Accuracy_train: 0.450000 Loss_valid:     1.4054 Accuracy_valid: 0.478000
# Epoch  4, CIFAR-10 Batch 2:  Loss_train:     1.3288 Accuracy_train: 0.475000 Loss_valid:     1.4363 Accuracy_valid: 0.468600
# Epoch  4, CIFAR-10 Batch 3:  Loss_train:     1.1013 Accuracy_train: 0.600000 Loss_valid:     1.3681 Accuracy_valid: 0.494800
# Epoch  4, CIFAR-10 Batch 4:  Loss_train:     1.3262 Accuracy_train: 0.475000 Loss_valid:     1.3665 Accuracy_valid: 0.492000
# Epoch  4, CIFAR-10 Batch 5:  Loss_train:     1.3687 Accuracy_train: 0.500000 Loss_valid:     1.3804 Accuracy_valid: 0.494600
# Epoch  5, CIFAR-10 Batch 1:  Loss_train:     1.2750 Accuracy_train: 0.450000 Loss_valid:     1.3028 Accuracy_valid: 0.518200
# Epoch  5, CIFAR-10 Batch 2:  Loss_train:     1.1131 Accuracy_train: 0.500000 Loss_valid:     1.3201 Accuracy_valid: 0.509800
# Epoch  5, CIFAR-10 Batch 3:  Loss_train:     0.9694 Accuracy_train: 0.675000 Loss_valid:     1.2514 Accuracy_valid: 0.541800
# Epoch  5, CIFAR-10 Batch 4:  Loss_train:     1.1031 Accuracy_train: 0.575000 Loss_valid:     1.2657 Accuracy_valid: 0.533600
# Epoch  5, CIFAR-10 Batch 5:  Loss_train:     1.1139 Accuracy_train: 0.625000 Loss_valid:     1.1960 Accuracy_valid: 0.566200
# Epoch  6, CIFAR-10 Batch 1:  Loss_train:     1.0972 Accuracy_train: 0.600000 Loss_valid:     1.2164 Accuracy_valid: 0.556600
# Epoch  6, CIFAR-10 Batch 2:  Loss_train:     0.9249 Accuracy_train: 0.650000 Loss_valid:     1.1799 Accuracy_valid: 0.576200
# Epoch  6, CIFAR-10 Batch 3:  Loss_train:     0.7927 Accuracy_train: 0.725000 Loss_valid:     1.1430 Accuracy_valid: 0.590000
# Epoch  6, CIFAR-10 Batch 4:  Loss_train:     0.9547 Accuracy_train: 0.650000 Loss_valid:     1.1117 Accuracy_valid: 0.598800
# Epoch  6, CIFAR-10 Batch 5:  Loss_train:     1.0073 Accuracy_train: 0.700000 Loss_valid:     1.1454 Accuracy_valid: 0.587000
# Epoch  7, CIFAR-10 Batch 1:  Loss_train:     0.9483 Accuracy_train: 0.625000 Loss_valid:     1.1016 Accuracy_valid: 0.602800
# Epoch  7, CIFAR-10 Batch 2:  Loss_train:     0.8011 Accuracy_train: 0.725000 Loss_valid:     1.1569 Accuracy_valid: 0.583200
# Epoch  7, CIFAR-10 Batch 3:  Loss_train:     0.6756 Accuracy_train: 0.725000 Loss_valid:     1.0642 Accuracy_valid: 0.621200
# Epoch  7, CIFAR-10 Batch 4:  Loss_train:     0.8728 Accuracy_train: 0.675000 Loss_valid:     1.0676 Accuracy_valid: 0.624000
# Epoch  7, CIFAR-10 Batch 5:  Loss_train:     0.8215 Accuracy_train: 0.700000 Loss_valid:     1.0462 Accuracy_valid: 0.631600
# Epoch  8, CIFAR-10 Batch 1:  Loss_train:     0.8475 Accuracy_train: 0.725000 Loss_valid:     1.1231 Accuracy_valid: 0.597800
# Epoch  8, CIFAR-10 Batch 2:  Loss_train:     0.6670 Accuracy_train: 0.800000 Loss_valid:     1.0561 Accuracy_valid: 0.620200
# Epoch  8, CIFAR-10 Batch 3:  Loss_train:     0.5110 Accuracy_train: 0.825000 Loss_valid:     1.0223 Accuracy_valid: 0.639000
# Epoch  8, CIFAR-10 Batch 4:  Loss_train:     0.7356 Accuracy_train: 0.725000 Loss_valid:     1.0052 Accuracy_valid: 0.638400
# Epoch  8, CIFAR-10 Batch 5:  Loss_train:     0.6275 Accuracy_train: 0.800000 Loss_valid:     0.9760 Accuracy_valid: 0.658600
# Epoch  9, CIFAR-10 Batch 1:  Loss_train:     0.6950 Accuracy_train: 0.725000 Loss_valid:     0.9962 Accuracy_valid: 0.648600
# Epoch  9, CIFAR-10 Batch 2:  Loss_train:     0.5561 Accuracy_train: 0.800000 Loss_valid:     1.0158 Accuracy_valid: 0.644400
# Epoch  9, CIFAR-10 Batch 3:  Loss_train:     0.4030 Accuracy_train: 0.850000 Loss_valid:     0.9499 Accuracy_valid: 0.664400
# Epoch  9, CIFAR-10 Batch 4:  Loss_train:     0.6427 Accuracy_train: 0.825000 Loss_valid:     0.9395 Accuracy_valid: 0.669200
# Epoch  9, CIFAR-10 Batch 5:  Loss_train:     0.5147 Accuracy_train: 0.825000 Loss_valid:     0.9308 Accuracy_valid: 0.672200
# Epoch 10, CIFAR-10 Batch 1:  Loss_train:     0.5487 Accuracy_train: 0.800000 Loss_valid:     0.9610 Accuracy_valid: 0.670600
# Epoch 10, CIFAR-10 Batch 2:  Loss_train:     0.4552 Accuracy_train: 0.875000 Loss_valid:     0.9161 Accuracy_valid: 0.681800
# Epoch 10, CIFAR-10 Batch 3:  Loss_train:     0.3562 Accuracy_train: 0.875000 Loss_valid:     0.9507 Accuracy_valid: 0.667200
# Epoch 10, CIFAR-10 Batch 4:  Loss_train:     0.4639 Accuracy_train: 0.925000 Loss_valid:     0.8918 Accuracy_valid: 0.692400
# Epoch 10, CIFAR-10 Batch 5:  Loss_train:     0.3843 Accuracy_train: 0.875000 Loss_valid:     0.8870 Accuracy_valid: 0.689000
# Epoch 11, CIFAR-10 Batch 1:  Loss_train:     0.4620 Accuracy_train: 0.825000 Loss_valid:     0.9328 Accuracy_valid: 0.681800
# Epoch 11, CIFAR-10 Batch 2:  Loss_train:     0.4095 Accuracy_train: 0.850000 Loss_valid:     0.8836 Accuracy_valid: 0.694600
# Epoch 11, CIFAR-10 Batch 3:  Loss_train:     0.2692 Accuracy_train: 0.950000 Loss_valid:     0.9086 Accuracy_valid: 0.685800
# Epoch 11, CIFAR-10 Batch 4:  Loss_train:     0.4292 Accuracy_train: 0.900000 Loss_valid:     0.8745 Accuracy_valid: 0.700000
# Epoch 11, CIFAR-10 Batch 5:  Loss_train:     0.3195 Accuracy_train: 0.925000 Loss_valid:     0.8716 Accuracy_valid: 0.700600
# Epoch 12, CIFAR-10 Batch 1:  Loss_train:     0.3342 Accuracy_train: 0.925000 Loss_valid:     0.8928 Accuracy_valid: 0.697400
# Epoch 12, CIFAR-10 Batch 2:  Loss_train:     0.3546 Accuracy_train: 0.875000 Loss_valid:     0.8661 Accuracy_valid: 0.705600
# Epoch 12, CIFAR-10 Batch 3:  Loss_train:     0.2574 Accuracy_train: 0.950000 Loss_valid:     0.9078 Accuracy_valid: 0.691000
# Epoch 12, CIFAR-10 Batch 4:  Loss_train:     0.3786 Accuracy_train: 0.925000 Loss_valid:     0.8346 Accuracy_valid: 0.714600
# Epoch 12, CIFAR-10 Batch 5:  Loss_train:     0.2428 Accuracy_train: 0.975000 Loss_valid:     0.8696 Accuracy_valid: 0.701400
# Epoch 13, CIFAR-10 Batch 1:  Loss_train:     0.2685 Accuracy_train: 0.950000 Loss_valid:     0.9058 Accuracy_valid: 0.694600
# Epoch 13, CIFAR-10 Batch 2:  Loss_train:     0.3041 Accuracy_train: 0.925000 Loss_valid:     0.8505 Accuracy_valid: 0.715600
# Epoch 13, CIFAR-10 Batch 3:  Loss_train:     0.2488 Accuracy_train: 0.950000 Loss_valid:     0.9433 Accuracy_valid: 0.678800
# Epoch 13, CIFAR-10 Batch 4:  Loss_train:     0.3039 Accuracy_train: 0.925000 Loss_valid:     0.8472 Accuracy_valid: 0.713400
# Epoch 13, CIFAR-10 Batch 5:  Loss_train:     0.2060 Accuracy_train: 0.975000 Loss_valid:     0.8313 Accuracy_valid: 0.716600
# Epoch 14, CIFAR-10 Batch 1:  Loss_train:     0.2108 Accuracy_train: 0.950000 Loss_valid:     0.8833 Accuracy_valid: 0.704400
# Epoch 14, CIFAR-10 Batch 2:  Loss_train:     0.2239 Accuracy_train: 0.950000 Loss_valid:     0.9038 Accuracy_valid: 0.694400
# Epoch 14, CIFAR-10 Batch 3:  Loss_train:     0.1912 Accuracy_train: 0.950000 Loss_valid:     0.9388 Accuracy_valid: 0.681400
# Epoch 14, CIFAR-10 Batch 4:  Loss_train:     0.2294 Accuracy_train: 0.925000 Loss_valid:     0.8632 Accuracy_valid: 0.710200
# Epoch 14, CIFAR-10 Batch 5:  Loss_train:     0.2131 Accuracy_train: 0.975000 Loss_valid:     0.8192 Accuracy_valid: 0.720800
# Epoch 15, CIFAR-10 Batch 1:  Loss_train:     0.1833 Accuracy_train: 1.000000 Loss_valid:     0.9142 Accuracy_valid: 0.698800
# Epoch 15, CIFAR-10 Batch 2:  Loss_train:     0.1924 Accuracy_train: 0.975000 Loss_valid:     0.8730 Accuracy_valid: 0.712200
# Epoch 15, CIFAR-10 Batch 3:  Loss_train:     0.1619 Accuracy_train: 0.950000 Loss_valid:     0.9256 Accuracy_valid: 0.698800
# Epoch 15, CIFAR-10 Batch 4:  Loss_train:     0.1972 Accuracy_train: 0.950000 Loss_valid:     0.8586 Accuracy_valid: 0.709200
# Epoch 15, CIFAR-10 Batch 5:  Loss_train:     0.1551 Accuracy_train: 1.000000 Loss_valid:     0.8258 Accuracy_valid: 0.719000
# Epoch 16, CIFAR-10 Batch 1:  Loss_train:     0.1423 Accuracy_train: 1.000000 Loss_valid:     0.9082 Accuracy_valid: 0.693800
# Epoch 16, CIFAR-10 Batch 2:  Loss_train:     0.1616 Accuracy_train: 0.975000 Loss_valid:     0.8366 Accuracy_valid: 0.724600
# Epoch 16, CIFAR-10 Batch 3:  Loss_train:     0.1322 Accuracy_train: 0.975000 Loss_valid:     0.9300 Accuracy_valid: 0.697400
# Epoch 16, CIFAR-10 Batch 4:  Loss_train:     0.1533 Accuracy_train: 1.000000 Loss_valid:     0.9185 Accuracy_valid: 0.701200
# Epoch 16, CIFAR-10 Batch 5:  Loss_train:     0.1174 Accuracy_train: 0.975000 Loss_valid:     0.8022 Accuracy_valid: 0.729200
# Epoch 17, CIFAR-10 Batch 1:  Loss_train:     0.1402 Accuracy_train: 1.000000 Loss_valid:     0.8771 Accuracy_valid: 0.702600
# Epoch 17, CIFAR-10 Batch 2:  Loss_train:     0.1271 Accuracy_train: 1.000000 Loss_valid:     0.8168 Accuracy_valid: 0.730600
# Epoch 17, CIFAR-10 Batch 3:  Loss_train:     0.1080 Accuracy_train: 1.000000 Loss_valid:     0.8749 Accuracy_valid: 0.711000
# Epoch 17, CIFAR-10 Batch 4:  Loss_train:     0.1360 Accuracy_train: 0.975000 Loss_valid:     0.8465 Accuracy_valid: 0.720800
# Epoch 17, CIFAR-10 Batch 5:  Loss_train:     0.0937 Accuracy_train: 1.000000 Loss_valid:     0.7940 Accuracy_valid: 0.736400
# Epoch 18, CIFAR-10 Batch 1:  Loss_train:     0.1082 Accuracy_train: 1.000000 Loss_valid:     0.8728 Accuracy_valid: 0.710200
# Epoch 18, CIFAR-10 Batch 2:  Loss_train:     0.0873 Accuracy_train: 1.000000 Loss_valid:     0.8405 Accuracy_valid: 0.728000
# Epoch 18, CIFAR-10 Batch 3:  Loss_train:     0.0785 Accuracy_train: 1.000000 Loss_valid:     0.8866 Accuracy_valid: 0.713000
# Epoch 18, CIFAR-10 Batch 4:  Loss_train:     0.1032 Accuracy_train: 1.000000 Loss_valid:     0.8466 Accuracy_valid: 0.731200
# Epoch 18, CIFAR-10 Batch 5:  Loss_train:     0.0753 Accuracy_train: 1.000000 Loss_valid:     0.8299 Accuracy_valid: 0.725200
# Epoch 19, CIFAR-10 Batch 1:  Loss_train:     0.0988 Accuracy_train: 1.000000 Loss_valid:     0.8159 Accuracy_valid: 0.731600
# Epoch 19, CIFAR-10 Batch 2:  Loss_train:     0.0851 Accuracy_train: 1.000000 Loss_valid:     0.8505 Accuracy_valid: 0.717800
# Epoch 19, CIFAR-10 Batch 3:  Loss_train:     0.0777 Accuracy_train: 0.975000 Loss_valid:     0.8477 Accuracy_valid: 0.729000
# Epoch 19, CIFAR-10 Batch 4:  Loss_train:     0.1384 Accuracy_train: 0.975000 Loss_valid:     0.8123 Accuracy_valid: 0.737800
# Epoch 19, CIFAR-10 Batch 5:  Loss_train:     0.0729 Accuracy_train: 1.000000 Loss_valid:     0.8291 Accuracy_valid: 0.735000
# Epoch 20, CIFAR-10 Batch 1:  Loss_train:     0.0923 Accuracy_train: 1.000000 Loss_valid:     0.8367 Accuracy_valid: 0.725400
# Epoch 20, CIFAR-10 Batch 2:  Loss_train:     0.0758 Accuracy_train: 1.000000 Loss_valid:     0.8442 Accuracy_valid: 0.726000
# Epoch 20, CIFAR-10 Batch 3:  Loss_train:     0.0595 Accuracy_train: 1.000000 Loss_valid:     0.9586 Accuracy_valid: 0.705600
# Epoch 20, CIFAR-10 Batch 4:  Loss_train:     0.0846 Accuracy_train: 1.000000 Loss_valid:     0.9597 Accuracy_valid: 0.708000
# Epoch 20, CIFAR-10 Batch 5:  Loss_train:     0.0500 Accuracy_train: 1.000000 Loss_valid:     0.8090 Accuracy_valid: 0.734800
# Epoch 21, CIFAR-10 Batch 1:  Loss_train:     0.1119 Accuracy_train: 1.000000 Loss_valid:     0.9382 Accuracy_valid: 0.694600
# Epoch 21, CIFAR-10 Batch 2:  Loss_train:     0.0794 Accuracy_train: 1.000000 Loss_valid:     0.9543 Accuracy_valid: 0.705400
# Epoch 21, CIFAR-10 Batch 3:  Loss_train:     0.0637 Accuracy_train: 1.000000 Loss_valid:     0.8927 Accuracy_valid: 0.720800
# Epoch 21, CIFAR-10 Batch 4:  Loss_train:     0.0756 Accuracy_train: 1.000000 Loss_valid:     0.8910 Accuracy_valid: 0.715400
# Epoch 21, CIFAR-10 Batch 5:  Loss_train:     0.0393 Accuracy_train: 1.000000 Loss_valid:     0.8264 Accuracy_valid: 0.739800
# Epoch 22, CIFAR-10 Batch 1:  Loss_train:     0.0757 Accuracy_train: 1.000000 Loss_valid:     0.9189 Accuracy_valid: 0.711000
# Epoch 22, CIFAR-10 Batch 2:  Loss_train:     0.0545 Accuracy_train: 1.000000 Loss_valid:     0.9658 Accuracy_valid: 0.703400
# Epoch 22, CIFAR-10 Batch 3:  Loss_train:     0.0586 Accuracy_train: 1.000000 Loss_valid:     0.8702 Accuracy_valid: 0.732000
# Epoch 22, CIFAR-10 Batch 4:  Loss_train:     0.0496 Accuracy_train: 1.000000 Loss_valid:     0.8721 Accuracy_valid: 0.729600
# Epoch 22, CIFAR-10 Batch 5:  Loss_train:     0.0335 Accuracy_train: 1.000000 Loss_valid:     0.8259 Accuracy_valid: 0.741400
# Epoch 23, CIFAR-10 Batch 1:  Loss_train:     0.0520 Accuracy_train: 1.000000 Loss_valid:     0.9141 Accuracy_valid: 0.719400
# Epoch 23, CIFAR-10 Batch 2:  Loss_train:     0.0372 Accuracy_train: 1.000000 Loss_valid:     0.8812 Accuracy_valid: 0.722200
# Epoch 23, CIFAR-10 Batch 3:  Loss_train:     0.0616 Accuracy_train: 1.000000 Loss_valid:     0.9039 Accuracy_valid: 0.727000
# Epoch 23, CIFAR-10 Batch 4:  Loss_train:     0.0407 Accuracy_train: 1.000000 Loss_valid:     0.8642 Accuracy_valid: 0.730600
# Epoch 23, CIFAR-10 Batch 5:  Loss_train:     0.0280 Accuracy_train: 1.000000 Loss_valid:     0.8400 Accuracy_valid: 0.743000
# Epoch 24, CIFAR-10 Batch 1:  Loss_train:     0.0542 Accuracy_train: 1.000000 Loss_valid:     0.9729 Accuracy_valid: 0.705800
# Epoch 24, CIFAR-10 Batch 2:  Loss_train:     0.0278 Accuracy_train: 1.000000 Loss_valid:     0.9541 Accuracy_valid: 0.721600
# Epoch 24, CIFAR-10 Batch 3:  Loss_train:     0.0714 Accuracy_train: 0.975000 Loss_valid:     1.0400 Accuracy_valid: 0.700400
# Epoch 24, CIFAR-10 Batch 4:  Loss_train:     0.0455 Accuracy_train: 1.000000 Loss_valid:     0.9126 Accuracy_valid: 0.723600
# Epoch 24, CIFAR-10 Batch 5:  Loss_train:     0.0284 Accuracy_train: 1.000000 Loss_valid:     0.8677 Accuracy_valid: 0.738200
# Epoch 25, CIFAR-10 Batch 1:  Loss_train:     0.0260 Accuracy_train: 1.000000 Loss_valid:     1.0003 Accuracy_valid: 0.708200
# Epoch 25, CIFAR-10 Batch 2:  Loss_train:     0.0289 Accuracy_train: 1.000000 Loss_valid:     0.9755 Accuracy_valid: 0.715400
# Epoch 25, CIFAR-10 Batch 3:  Loss_train:     0.0454 Accuracy_train: 1.000000 Loss_valid:     0.9375 Accuracy_valid: 0.728800
# Epoch 25, CIFAR-10 Batch 4:  Loss_train:     0.0502 Accuracy_train: 1.000000 Loss_valid:     0.9071 Accuracy_valid: 0.720000
# Epoch 25, CIFAR-10 Batch 5:  Loss_train:     0.0219 Accuracy_train: 1.000000 Loss_valid:     0.8712 Accuracy_valid: 0.733000
# Epoch 26, CIFAR-10 Batch 1:  Loss_train:     0.0184 Accuracy_train: 1.000000 Loss_valid:     0.9725 Accuracy_valid: 0.725200
# Epoch 26, CIFAR-10 Batch 2:  Loss_train:     0.0201 Accuracy_train: 1.000000 Loss_valid:     0.9235 Accuracy_valid: 0.723600
# Epoch 26, CIFAR-10 Batch 3:  Loss_train:     0.0318 Accuracy_train: 1.000000 Loss_valid:     0.9939 Accuracy_valid: 0.717600
# Epoch 26, CIFAR-10 Batch 4:  Loss_train:     0.0321 Accuracy_train: 1.000000 Loss_valid:     0.9051 Accuracy_valid: 0.726000
# Epoch 26, CIFAR-10 Batch 5:  Loss_train:     0.0141 Accuracy_train: 1.000000 Loss_valid:     0.8880 Accuracy_valid: 0.738800
# Epoch 27, CIFAR-10 Batch 1:  Loss_train:     0.0163 Accuracy_train: 1.000000 Loss_valid:     0.9693 Accuracy_valid: 0.734800
# Epoch 27, CIFAR-10 Batch 2:  Loss_train:     0.0317 Accuracy_train: 1.000000 Loss_valid:     1.0775 Accuracy_valid: 0.700800
# Epoch 27, CIFAR-10 Batch 3:  Loss_train:     0.0286 Accuracy_train: 1.000000 Loss_valid:     0.9508 Accuracy_valid: 0.726000
# Epoch 27, CIFAR-10 Batch 4:  Loss_train:     0.0162 Accuracy_train: 1.000000 Loss_valid:     0.9329 Accuracy_valid: 0.725200
# Epoch 27, CIFAR-10 Batch 5:  Loss_train:     0.0153 Accuracy_train: 1.000000 Loss_valid:     0.9251 Accuracy_valid: 0.736200
# Epoch 28, CIFAR-10 Batch 1:  Loss_train:     0.0109 Accuracy_train: 1.000000 Loss_valid:     0.9953 Accuracy_valid: 0.729400
# Epoch 28, CIFAR-10 Batch 2:  Loss_train:     0.0258 Accuracy_train: 1.000000 Loss_valid:     1.1112 Accuracy_valid: 0.705600
# Epoch 28, CIFAR-10 Batch 3:  Loss_train:     0.0140 Accuracy_train: 1.000000 Loss_valid:     1.0297 Accuracy_valid: 0.726800
# Epoch 28, CIFAR-10 Batch 4:  Loss_train:     0.0104 Accuracy_train: 1.000000 Loss_valid:     0.9686 Accuracy_valid: 0.730000
# Epoch 28, CIFAR-10 Batch 5:  Loss_train:     0.0122 Accuracy_train: 1.000000 Loss_valid:     0.9760 Accuracy_valid: 0.732600
# Epoch 29, CIFAR-10 Batch 1:  Loss_train:     0.0118 Accuracy_train: 1.000000 Loss_valid:     1.0733 Accuracy_valid: 0.714400
# Epoch 29, CIFAR-10 Batch 2:  Loss_train:     0.0159 Accuracy_train: 1.000000 Loss_valid:     1.0380 Accuracy_valid: 0.715000
# Epoch 29, CIFAR-10 Batch 3:  Loss_train:     0.0168 Accuracy_train: 1.000000 Loss_valid:     0.9952 Accuracy_valid: 0.724800
# Epoch 29, CIFAR-10 Batch 4:  Loss_train:     0.0115 Accuracy_train: 1.000000 Loss_valid:     1.0250 Accuracy_valid: 0.724600
# Epoch 29, CIFAR-10 Batch 5:  Loss_train:     0.0107 Accuracy_train: 1.000000 Loss_valid:     0.9604 Accuracy_valid: 0.739600
# Epoch 30, CIFAR-10 Batch 1:  Loss_train:     0.0147 Accuracy_train: 1.000000 Loss_valid:     1.0450 Accuracy_valid: 0.728000
# Epoch 30, CIFAR-10 Batch 2:  Loss_train:     0.0119 Accuracy_train: 1.000000 Loss_valid:     1.1014 Accuracy_valid: 0.711200
# Epoch 30, CIFAR-10 Batch 3:  Loss_train:     0.0141 Accuracy_train: 1.000000 Loss_valid:     1.0533 Accuracy_valid: 0.723200
# Epoch 30, CIFAR-10 Batch 4:  Loss_train:     0.0124 Accuracy_train: 1.000000 Loss_valid:     1.0432 Accuracy_valid: 0.724400
# Epoch 30, CIFAR-10 Batch 5:  Loss_train:     0.0089 Accuracy_train: 1.000000 Loss_valid:     1.0196 Accuracy_valid: 0.730200
# Epoch 31, CIFAR-10 Batch 1:  Loss_train:     0.0058 Accuracy_train: 1.000000 Loss_valid:     1.1392 Accuracy_valid: 0.709400
# Epoch 31, CIFAR-10 Batch 2:  Loss_train:     0.0218 Accuracy_train: 1.000000 Loss_valid:     1.0278 Accuracy_valid: 0.722600
# Epoch 31, CIFAR-10 Batch 3:  Loss_train:     0.0092 Accuracy_train: 1.000000 Loss_valid:     1.0551 Accuracy_valid: 0.729400
# Epoch 31, CIFAR-10 Batch 4:  Loss_train:     0.0046 Accuracy_train: 1.000000 Loss_valid:     1.0835 Accuracy_valid: 0.725800
# Epoch 31, CIFAR-10 Batch 5:  Loss_train:     0.0028 Accuracy_train: 1.000000 Loss_valid:     1.0526 Accuracy_valid: 0.728600
# Epoch 32, CIFAR-10 Batch 1:  Loss_train:     0.0110 Accuracy_train: 1.000000 Loss_valid:     1.1060 Accuracy_valid: 0.723400
# Epoch 32, CIFAR-10 Batch 2:  Loss_train:     0.0067 Accuracy_train: 1.000000 Loss_valid:     1.0802 Accuracy_valid: 0.726000
# Epoch 32, CIFAR-10 Batch 3:  Loss_train:     0.0085 Accuracy_train: 1.000000 Loss_valid:     1.1326 Accuracy_valid: 0.721000
# Epoch 32, CIFAR-10 Batch 4:  Loss_train:     0.0039 Accuracy_train: 1.000000 Loss_valid:     1.0852 Accuracy_valid: 0.727400
# Epoch 32, CIFAR-10 Batch 5:  Loss_train:     0.0030 Accuracy_train: 1.000000 Loss_valid:     1.0449 Accuracy_valid: 0.733000
# Epoch 33, CIFAR-10 Batch 1:  Loss_train:     0.0065 Accuracy_train: 1.000000 Loss_valid:     1.1431 Accuracy_valid: 0.716200
# Epoch 33, CIFAR-10 Batch 2:  Loss_train:     0.0075 Accuracy_train: 1.000000 Loss_valid:     1.0113 Accuracy_valid: 0.739400
# Epoch 33, CIFAR-10 Batch 3:  Loss_train:     0.0067 Accuracy_train: 1.000000 Loss_valid:     1.1151 Accuracy_valid: 0.721200
# Epoch 33, CIFAR-10 Batch 4:  Loss_train:     0.0055 Accuracy_train: 1.000000 Loss_valid:     1.1443 Accuracy_valid: 0.711800
# Epoch 33, CIFAR-10 Batch 5:  Loss_train:     0.0054 Accuracy_train: 1.000000 Loss_valid:     1.0625 Accuracy_valid: 0.733600
# Epoch 34, CIFAR-10 Batch 1:  Loss_train:     0.0067 Accuracy_train: 1.000000 Loss_valid:     1.1453 Accuracy_valid: 0.715200
# Epoch 34, CIFAR-10 Batch 2:  Loss_train:     0.0072 Accuracy_train: 1.000000 Loss_valid:     1.0157 Accuracy_valid: 0.738400
# Epoch 34, CIFAR-10 Batch 3:  Loss_train:     0.0089 Accuracy_train: 1.000000 Loss_valid:     1.0541 Accuracy_valid: 0.726200
# Epoch 34, CIFAR-10 Batch 4:  Loss_train:     0.0044 Accuracy_train: 1.000000 Loss_valid:     1.0646 Accuracy_valid: 0.729600
# Epoch 34, CIFAR-10 Batch 5:  Loss_train:     0.0034 Accuracy_train: 1.000000 Loss_valid:     1.0947 Accuracy_valid: 0.732400
# Epoch 35, CIFAR-10 Batch 1:  Loss_train:     0.0091 Accuracy_train: 1.000000 Loss_valid:     1.1940 Accuracy_valid: 0.706200
# Epoch 35, CIFAR-10 Batch 2:  Loss_train:     0.0056 Accuracy_train: 1.000000 Loss_valid:     1.0308 Accuracy_valid: 0.736800
# Epoch 35, CIFAR-10 Batch 3:  Loss_train:     0.0087 Accuracy_train: 1.000000 Loss_valid:     1.1436 Accuracy_valid: 0.720200
# Epoch 35, CIFAR-10 Batch 4:  Loss_train:     0.0039 Accuracy_train: 1.000000 Loss_valid:     1.0769 Accuracy_valid: 0.723800
# Epoch 35, CIFAR-10 Batch 5:  Loss_train:     0.0070 Accuracy_train: 1.000000 Loss_valid:     1.1216 Accuracy_valid: 0.731800
# Epoch 36, CIFAR-10 Batch 1:  Loss_train:     0.0048 Accuracy_train: 1.000000 Loss_valid:     1.1548 Accuracy_valid: 0.723600
# Epoch 36, CIFAR-10 Batch 2:  Loss_train:     0.0106 Accuracy_train: 1.000000 Loss_valid:     1.0642 Accuracy_valid: 0.729800
# Epoch 36, CIFAR-10 Batch 3:  Loss_train:     0.0142 Accuracy_train: 1.000000 Loss_valid:     1.1305 Accuracy_valid: 0.720600
# Epoch 36, CIFAR-10 Batch 4:  Loss_train:     0.0058 Accuracy_train: 1.000000 Loss_valid:     1.1283 Accuracy_valid: 0.725800
# Epoch 36, CIFAR-10 Batch 5:  Loss_train:     0.0070 Accuracy_train: 1.000000 Loss_valid:     1.1785 Accuracy_valid: 0.726800
# Epoch 37, CIFAR-10 Batch 1:  Loss_train:     0.0059 Accuracy_train: 1.000000 Loss_valid:     1.1644 Accuracy_valid: 0.721600
# Epoch 37, CIFAR-10 Batch 2:  Loss_train:     0.0070 Accuracy_train: 1.000000 Loss_valid:     1.0794 Accuracy_valid: 0.728600
# Epoch 37, CIFAR-10 Batch 3:  Loss_train:     0.0096 Accuracy_train: 1.000000 Loss_valid:     1.1944 Accuracy_valid: 0.708200
# Epoch 37, CIFAR-10 Batch 4:  Loss_train:     0.0147 Accuracy_train: 1.000000 Loss_valid:     1.1075 Accuracy_valid: 0.725800
# Epoch 37, CIFAR-10 Batch 5:  Loss_train:     0.0015 Accuracy_train: 1.000000 Loss_valid:     1.1634 Accuracy_valid: 0.731400
# Epoch 38, CIFAR-10 Batch 1:  Loss_train:     0.0044 Accuracy_train: 1.000000 Loss_valid:     1.2231 Accuracy_valid: 0.717600
# Epoch 38, CIFAR-10 Batch 2:  Loss_train:     0.0106 Accuracy_train: 1.000000 Loss_valid:     1.0891 Accuracy_valid: 0.737400
# Epoch 38, CIFAR-10 Batch 3:  Loss_train:     0.0108 Accuracy_train: 1.000000 Loss_valid:     1.1589 Accuracy_valid: 0.722000
# Epoch 38, CIFAR-10 Batch 4:  Loss_train:     0.0129 Accuracy_train: 1.000000 Loss_valid:     1.1649 Accuracy_valid: 0.718400
# Epoch 38, CIFAR-10 Batch 5:  Loss_train:     0.0021 Accuracy_train: 1.000000 Loss_valid:     1.2328 Accuracy_valid: 0.722600
# Epoch 39, CIFAR-10 Batch 1:  Loss_train:     0.0037 Accuracy_train: 1.000000 Loss_valid:     1.2000 Accuracy_valid: 0.725600
# Epoch 39, CIFAR-10 Batch 2:  Loss_train:     0.0058 Accuracy_train: 1.000000 Loss_valid:     1.1122 Accuracy_valid: 0.725200
# Epoch 39, CIFAR-10 Batch 3:  Loss_train:     0.0092 Accuracy_train: 1.000000 Loss_valid:     1.1363 Accuracy_valid: 0.729400
# Epoch 39, CIFAR-10 Batch 4:  Loss_train:     0.0035 Accuracy_train: 1.000000 Loss_valid:     1.1238 Accuracy_valid: 0.719600
# Epoch 39, CIFAR-10 Batch 5:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     1.1472 Accuracy_valid: 0.735400
# Epoch 40, CIFAR-10 Batch 1:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     1.1405 Accuracy_valid: 0.732200
# Epoch 40, CIFAR-10 Batch 2:  Loss_train:     0.0300 Accuracy_train: 0.975000 Loss_valid:     1.1697 Accuracy_valid: 0.710200
# Epoch 40, CIFAR-10 Batch 3:  Loss_train:     0.0054 Accuracy_train: 1.000000 Loss_valid:     1.1506 Accuracy_valid: 0.730000
# Epoch 40, CIFAR-10 Batch 4:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     1.1570 Accuracy_valid: 0.710400
# Epoch 40, CIFAR-10 Batch 5:  Loss_train:     0.0017 Accuracy_train: 1.000000 Loss_valid:     1.2106 Accuracy_valid: 0.736800
# Epoch 41, CIFAR-10 Batch 1:  Loss_train:     0.0064 Accuracy_train: 1.000000 Loss_valid:     1.1395 Accuracy_valid: 0.725400
# Epoch 41, CIFAR-10 Batch 2:  Loss_train:     0.0051 Accuracy_train: 1.000000 Loss_valid:     1.1815 Accuracy_valid: 0.716400
# Epoch 41, CIFAR-10 Batch 3:  Loss_train:     0.0063 Accuracy_train: 1.000000 Loss_valid:     1.2020 Accuracy_valid: 0.719200
# Epoch 41, CIFAR-10 Batch 4:  Loss_train:     0.0033 Accuracy_train: 1.000000 Loss_valid:     1.1951 Accuracy_valid: 0.716200
# Epoch 41, CIFAR-10 Batch 5:  Loss_train:     0.0144 Accuracy_train: 1.000000 Loss_valid:     1.2110 Accuracy_valid: 0.724400
# Epoch 42, CIFAR-10 Batch 1:  Loss_train:     0.0063 Accuracy_train: 1.000000 Loss_valid:     1.2654 Accuracy_valid: 0.721600
# Epoch 42, CIFAR-10 Batch 2:  Loss_train:     0.0116 Accuracy_train: 1.000000 Loss_valid:     1.1671 Accuracy_valid: 0.725600
# Epoch 42, CIFAR-10 Batch 3:  Loss_train:     0.0059 Accuracy_train: 1.000000 Loss_valid:     1.2334 Accuracy_valid: 0.726000
# Epoch 42, CIFAR-10 Batch 4:  Loss_train:     0.0054 Accuracy_train: 1.000000 Loss_valid:     1.2292 Accuracy_valid: 0.710800
# Epoch 42, CIFAR-10 Batch 5:  Loss_train:     0.0024 Accuracy_train: 1.000000 Loss_valid:     1.2348 Accuracy_valid: 0.725000
# Epoch 43, CIFAR-10 Batch 1:  Loss_train:     0.0052 Accuracy_train: 1.000000 Loss_valid:     1.2443 Accuracy_valid: 0.723600
# Epoch 43, CIFAR-10 Batch 2:  Loss_train:     0.0027 Accuracy_train: 1.000000 Loss_valid:     1.1801 Accuracy_valid: 0.722600
# Epoch 43, CIFAR-10 Batch 3:  Loss_train:     0.0035 Accuracy_train: 1.000000 Loss_valid:     1.2665 Accuracy_valid: 0.719400
# Epoch 43, CIFAR-10 Batch 4:  Loss_train:     0.0032 Accuracy_train: 1.000000 Loss_valid:     1.1620 Accuracy_valid: 0.714400
# Epoch 43, CIFAR-10 Batch 5:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.1932 Accuracy_valid: 0.733000
# Epoch 44, CIFAR-10 Batch 1:  Loss_train:     0.0032 Accuracy_train: 1.000000 Loss_valid:     1.1994 Accuracy_valid: 0.731200
# Epoch 44, CIFAR-10 Batch 2:  Loss_train:     0.0032 Accuracy_train: 1.000000 Loss_valid:     1.1385 Accuracy_valid: 0.732800
# Epoch 44, CIFAR-10 Batch 3:  Loss_train:     0.0027 Accuracy_train: 1.000000 Loss_valid:     1.2946 Accuracy_valid: 0.727000
# Epoch 44, CIFAR-10 Batch 4:  Loss_train:     0.0037 Accuracy_train: 1.000000 Loss_valid:     1.2164 Accuracy_valid: 0.712000
# Epoch 44, CIFAR-10 Batch 5:  Loss_train:     0.0011 Accuracy_train: 1.000000 Loss_valid:     1.2246 Accuracy_valid: 0.733000
# Epoch 45, CIFAR-10 Batch 1:  Loss_train:     0.0019 Accuracy_train: 1.000000 Loss_valid:     1.2804 Accuracy_valid: 0.729000
# Epoch 45, CIFAR-10 Batch 2:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.1867 Accuracy_valid: 0.743400
# Epoch 45, CIFAR-10 Batch 3:  Loss_train:     0.0021 Accuracy_train: 1.000000 Loss_valid:     1.2402 Accuracy_valid: 0.728200
# Epoch 45, CIFAR-10 Batch 4:  Loss_train:     0.0030 Accuracy_train: 1.000000 Loss_valid:     1.2043 Accuracy_valid: 0.713000
# Epoch 45, CIFAR-10 Batch 5:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.2467 Accuracy_valid: 0.731800
# Epoch 46, CIFAR-10 Batch 1:  Loss_train:     0.0068 Accuracy_train: 1.000000 Loss_valid:     1.2473 Accuracy_valid: 0.726400
# Epoch 46, CIFAR-10 Batch 2:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.2192 Accuracy_valid: 0.736800
# Epoch 46, CIFAR-10 Batch 3:  Loss_train:     0.0024 Accuracy_train: 1.000000 Loss_valid:     1.2338 Accuracy_valid: 0.730800
# Epoch 46, CIFAR-10 Batch 4:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.2276 Accuracy_valid: 0.712800
# Epoch 46, CIFAR-10 Batch 5:  Loss_train:     0.0025 Accuracy_train: 1.000000 Loss_valid:     1.2635 Accuracy_valid: 0.725800
# Epoch 47, CIFAR-10 Batch 1:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.2248 Accuracy_valid: 0.748400
# Epoch 47, CIFAR-10 Batch 2:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.2533 Accuracy_valid: 0.732400
# Epoch 47, CIFAR-10 Batch 3:  Loss_train:     0.0020 Accuracy_train: 1.000000 Loss_valid:     1.4011 Accuracy_valid: 0.711800
# Epoch 47, CIFAR-10 Batch 4:  Loss_train:     0.0027 Accuracy_train: 1.000000 Loss_valid:     1.2470 Accuracy_valid: 0.711800
# Epoch 47, CIFAR-10 Batch 5:  Loss_train:     0.0015 Accuracy_train: 1.000000 Loss_valid:     1.3057 Accuracy_valid: 0.720600
# Epoch 48, CIFAR-10 Batch 1:  Loss_train:     0.0014 Accuracy_train: 1.000000 Loss_valid:     1.2808 Accuracy_valid: 0.736600
# Epoch 48, CIFAR-10 Batch 2:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.2438 Accuracy_valid: 0.735600
# Epoch 48, CIFAR-10 Batch 3:  Loss_train:     0.0015 Accuracy_train: 1.000000 Loss_valid:     1.2331 Accuracy_valid: 0.739400
# Epoch 48, CIFAR-10 Batch 4:  Loss_train:     0.0019 Accuracy_train: 1.000000 Loss_valid:     1.1785 Accuracy_valid: 0.718000
# Epoch 48, CIFAR-10 Batch 5:  Loss_train:     0.0035 Accuracy_train: 1.000000 Loss_valid:     1.3089 Accuracy_valid: 0.710200
# Epoch 49, CIFAR-10 Batch 1:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.2208 Accuracy_valid: 0.738000
# Epoch 49, CIFAR-10 Batch 2:  Loss_train:     0.0019 Accuracy_train: 1.000000 Loss_valid:     1.2751 Accuracy_valid: 0.726200
# Epoch 49, CIFAR-10 Batch 3:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     1.3313 Accuracy_valid: 0.718400
# Epoch 49, CIFAR-10 Batch 4:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     1.3534 Accuracy_valid: 0.709600
# Epoch 49, CIFAR-10 Batch 5:  Loss_train:     0.0020 Accuracy_train: 1.000000 Loss_valid:     1.2386 Accuracy_valid: 0.730800
# Epoch 50, CIFAR-10 Batch 1:  Loss_train:     0.0015 Accuracy_train: 1.000000 Loss_valid:     1.2122 Accuracy_valid: 0.741200
# Epoch 50, CIFAR-10 Batch 2:  Loss_train:     0.0030 Accuracy_train: 1.000000 Loss_valid:     1.2533 Accuracy_valid: 0.724600
# Epoch 50, CIFAR-10 Batch 3:  Loss_train:     0.0038 Accuracy_train: 1.000000 Loss_valid:     1.3157 Accuracy_valid: 0.724000
# Epoch 50, CIFAR-10 Batch 4:  Loss_train:     0.0014 Accuracy_train: 1.000000 Loss_valid:     1.2972 Accuracy_valid: 0.720800
# Epoch 50, CIFAR-10 Batch 5:  Loss_train:     0.0014 Accuracy_train: 1.000000 Loss_valid:     1.3268 Accuracy_valid: 0.722600
# Epoch 51, CIFAR-10 Batch 1:  Loss_train:     0.0050 Accuracy_train: 1.000000 Loss_valid:     1.2926 Accuracy_valid: 0.734400
# Epoch 51, CIFAR-10 Batch 2:  Loss_train:     0.0021 Accuracy_train: 1.000000 Loss_valid:     1.3084 Accuracy_valid: 0.728600
# Epoch 51, CIFAR-10 Batch 3:  Loss_train:     0.0024 Accuracy_train: 1.000000 Loss_valid:     1.2611 Accuracy_valid: 0.735600
# Epoch 51, CIFAR-10 Batch 4:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.2905 Accuracy_valid: 0.725000
# Epoch 51, CIFAR-10 Batch 5:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.2841 Accuracy_valid: 0.729200
# Epoch 52, CIFAR-10 Batch 1:  Loss_train:     0.0023 Accuracy_train: 1.000000 Loss_valid:     1.2534 Accuracy_valid: 0.735400
# Epoch 52, CIFAR-10 Batch 2:  Loss_train:     0.0014 Accuracy_train: 1.000000 Loss_valid:     1.2907 Accuracy_valid: 0.725000
# Epoch 52, CIFAR-10 Batch 3:  Loss_train:     0.0012 Accuracy_train: 1.000000 Loss_valid:     1.3032 Accuracy_valid: 0.729800
# Epoch 52, CIFAR-10 Batch 4:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.2242 Accuracy_valid: 0.725200
# Epoch 52, CIFAR-10 Batch 5:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.2734 Accuracy_valid: 0.740000
# Epoch 53, CIFAR-10 Batch 1:  Loss_train:     0.0009 Accuracy_train: 1.000000 Loss_valid:     1.2631 Accuracy_valid: 0.737600
# Epoch 53, CIFAR-10 Batch 2:  Loss_train:     0.0015 Accuracy_train: 1.000000 Loss_valid:     1.3634 Accuracy_valid: 0.724000
# Epoch 53, CIFAR-10 Batch 3:  Loss_train:     0.0052 Accuracy_train: 1.000000 Loss_valid:     1.2450 Accuracy_valid: 0.739000
# Epoch 53, CIFAR-10 Batch 4:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.2582 Accuracy_valid: 0.729400
# Epoch 53, CIFAR-10 Batch 5:  Loss_train:     0.0011 Accuracy_train: 1.000000 Loss_valid:     1.3165 Accuracy_valid: 0.724800
# Epoch 54, CIFAR-10 Batch 1:  Loss_train:     0.0020 Accuracy_train: 1.000000 Loss_valid:     1.2406 Accuracy_valid: 0.743200
# Epoch 54, CIFAR-10 Batch 2:  Loss_train:     0.0019 Accuracy_train: 1.000000 Loss_valid:     1.3125 Accuracy_valid: 0.721800
# Epoch 54, CIFAR-10 Batch 3:  Loss_train:     0.0011 Accuracy_train: 1.000000 Loss_valid:     1.2511 Accuracy_valid: 0.746600
# Epoch 54, CIFAR-10 Batch 4:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3138 Accuracy_valid: 0.733000
# Epoch 54, CIFAR-10 Batch 5:  Loss_train:     0.0014 Accuracy_train: 1.000000 Loss_valid:     1.3387 Accuracy_valid: 0.742000
# Epoch 55, CIFAR-10 Batch 1:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.3120 Accuracy_valid: 0.735400
# Epoch 55, CIFAR-10 Batch 2:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.2930 Accuracy_valid: 0.740600
# Epoch 55, CIFAR-10 Batch 3:  Loss_train:     0.0071 Accuracy_train: 1.000000 Loss_valid:     1.3046 Accuracy_valid: 0.739600
# Epoch 55, CIFAR-10 Batch 4:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.3407 Accuracy_valid: 0.720400
# Epoch 55, CIFAR-10 Batch 5:  Loss_train:     0.0030 Accuracy_train: 1.000000 Loss_valid:     1.2894 Accuracy_valid: 0.743800
# Epoch 56, CIFAR-10 Batch 1:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.3088 Accuracy_valid: 0.740200
# Epoch 56, CIFAR-10 Batch 2:  Loss_train:     0.0020 Accuracy_train: 1.000000 Loss_valid:     1.2448 Accuracy_valid: 0.734400
# Epoch 56, CIFAR-10 Batch 3:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     1.2894 Accuracy_valid: 0.735600
# Epoch 56, CIFAR-10 Batch 4:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.3327 Accuracy_valid: 0.735200
# Epoch 56, CIFAR-10 Batch 5:  Loss_train:     0.0022 Accuracy_train: 1.000000 Loss_valid:     1.3644 Accuracy_valid: 0.732000
# Epoch 57, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3406 Accuracy_valid: 0.736200
# Epoch 57, CIFAR-10 Batch 2:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.3310 Accuracy_valid: 0.739200
# Epoch 57, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3168 Accuracy_valid: 0.743600
# Epoch 57, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.2962 Accuracy_valid: 0.729800
# Epoch 57, CIFAR-10 Batch 5:  Loss_train:     0.0020 Accuracy_train: 1.000000 Loss_valid:     1.3478 Accuracy_valid: 0.736800
# Epoch 58, CIFAR-10 Batch 1:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     1.3115 Accuracy_valid: 0.737800
# Epoch 58, CIFAR-10 Batch 2:  Loss_train:     0.0022 Accuracy_train: 1.000000 Loss_valid:     1.3616 Accuracy_valid: 0.733000
# Epoch 58, CIFAR-10 Batch 3:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.2916 Accuracy_valid: 0.742600
# Epoch 58, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3294 Accuracy_valid: 0.739400
# Epoch 58, CIFAR-10 Batch 5:  Loss_train:     0.0018 Accuracy_train: 1.000000 Loss_valid:     1.4126 Accuracy_valid: 0.733800
# Epoch 59, CIFAR-10 Batch 1:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.3109 Accuracy_valid: 0.737000
# Epoch 59, CIFAR-10 Batch 2:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3285 Accuracy_valid: 0.742200
# Epoch 59, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3645 Accuracy_valid: 0.740000
# Epoch 59, CIFAR-10 Batch 4:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.2884 Accuracy_valid: 0.734600
# Epoch 59, CIFAR-10 Batch 5:  Loss_train:     0.0026 Accuracy_train: 1.000000 Loss_valid:     1.4090 Accuracy_valid: 0.728800
# Epoch 60, CIFAR-10 Batch 1:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3790 Accuracy_valid: 0.728600
# Epoch 60, CIFAR-10 Batch 2:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3846 Accuracy_valid: 0.734200
# Epoch 60, CIFAR-10 Batch 3:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.3277 Accuracy_valid: 0.736600
# Epoch 60, CIFAR-10 Batch 4:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3696 Accuracy_valid: 0.718600
# Epoch 60, CIFAR-10 Batch 5:  Loss_train:     0.0014 Accuracy_train: 1.000000 Loss_valid:     1.4364 Accuracy_valid: 0.729400
# Epoch 61, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4230 Accuracy_valid: 0.724200
# Epoch 61, CIFAR-10 Batch 2:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.3592 Accuracy_valid: 0.732400
# Epoch 61, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3496 Accuracy_valid: 0.735600
# Epoch 61, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3333 Accuracy_valid: 0.737600
# Epoch 61, CIFAR-10 Batch 5:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.4363 Accuracy_valid: 0.727600
# Epoch 62, CIFAR-10 Batch 1:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.3638 Accuracy_valid: 0.737000
# Epoch 62, CIFAR-10 Batch 2:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.2956 Accuracy_valid: 0.738600
# Epoch 62, CIFAR-10 Batch 3:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.3309 Accuracy_valid: 0.747600
# Epoch 62, CIFAR-10 Batch 4:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3285 Accuracy_valid: 0.739000
# Epoch 62, CIFAR-10 Batch 5:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.4023 Accuracy_valid: 0.735400
# Epoch 63, CIFAR-10 Batch 1:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3986 Accuracy_valid: 0.729200
# Epoch 63, CIFAR-10 Batch 2:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.3465 Accuracy_valid: 0.741200
# Epoch 63, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3301 Accuracy_valid: 0.746200
# Epoch 63, CIFAR-10 Batch 4:  Loss_train:     0.0012 Accuracy_train: 1.000000 Loss_valid:     1.3750 Accuracy_valid: 0.742000
# Epoch 63, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.3891 Accuracy_valid: 0.739200
# Epoch 64, CIFAR-10 Batch 1:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.4064 Accuracy_valid: 0.733400
# Epoch 64, CIFAR-10 Batch 2:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.3319 Accuracy_valid: 0.739000
# Epoch 64, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.3242 Accuracy_valid: 0.748600
# Epoch 64, CIFAR-10 Batch 4:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.2847 Accuracy_valid: 0.738400
# Epoch 64, CIFAR-10 Batch 5:  Loss_train:     0.0034 Accuracy_train: 1.000000 Loss_valid:     1.3711 Accuracy_valid: 0.728800
# Epoch 65, CIFAR-10 Batch 1:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3561 Accuracy_valid: 0.731200
# Epoch 65, CIFAR-10 Batch 2:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.2899 Accuracy_valid: 0.745200
# Epoch 65, CIFAR-10 Batch 3:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.3607 Accuracy_valid: 0.741600
# Epoch 65, CIFAR-10 Batch 4:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3349 Accuracy_valid: 0.735000
# Epoch 65, CIFAR-10 Batch 5:  Loss_train:     0.0118 Accuracy_train: 1.000000 Loss_valid:     1.4712 Accuracy_valid: 0.728600
# Epoch 66, CIFAR-10 Batch 1:  Loss_train:     0.0021 Accuracy_train: 1.000000 Loss_valid:     1.4898 Accuracy_valid: 0.730600
# Epoch 66, CIFAR-10 Batch 2:  Loss_train:     0.0035 Accuracy_train: 1.000000 Loss_valid:     1.3539 Accuracy_valid: 0.741600
# Epoch 66, CIFAR-10 Batch 3:  Loss_train:     0.0031 Accuracy_train: 1.000000 Loss_valid:     1.3597 Accuracy_valid: 0.746400
# Epoch 66, CIFAR-10 Batch 4:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.3717 Accuracy_valid: 0.735600
# Epoch 66, CIFAR-10 Batch 5:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3543 Accuracy_valid: 0.745600
# Epoch 67, CIFAR-10 Batch 1:  Loss_train:     0.0009 Accuracy_train: 1.000000 Loss_valid:     1.3797 Accuracy_valid: 0.742200
# Epoch 67, CIFAR-10 Batch 2:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     1.3930 Accuracy_valid: 0.741200
# Epoch 67, CIFAR-10 Batch 3:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.3667 Accuracy_valid: 0.748400
# Epoch 67, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3979 Accuracy_valid: 0.736800
# Epoch 67, CIFAR-10 Batch 5:  Loss_train:     0.0019 Accuracy_train: 1.000000 Loss_valid:     1.4328 Accuracy_valid: 0.741000
# Epoch 68, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4083 Accuracy_valid: 0.746000
# Epoch 68, CIFAR-10 Batch 2:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.4047 Accuracy_valid: 0.733800
# Epoch 68, CIFAR-10 Batch 3:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.3356 Accuracy_valid: 0.743000
# Epoch 68, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3828 Accuracy_valid: 0.737400
# Epoch 68, CIFAR-10 Batch 5:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.3980 Accuracy_valid: 0.742200
# Epoch 69, CIFAR-10 Batch 1:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.3668 Accuracy_valid: 0.743800
# Epoch 69, CIFAR-10 Batch 2:  Loss_train:     0.0015 Accuracy_train: 1.000000 Loss_valid:     1.4250 Accuracy_valid: 0.732800
# Epoch 69, CIFAR-10 Batch 3:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     1.3692 Accuracy_valid: 0.738200
# Epoch 69, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4293 Accuracy_valid: 0.733000
# Epoch 69, CIFAR-10 Batch 5:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.4473 Accuracy_valid: 0.734400
# Epoch 70, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.5055 Accuracy_valid: 0.726000
# Epoch 70, CIFAR-10 Batch 2:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.3746 Accuracy_valid: 0.748800
# Epoch 70, CIFAR-10 Batch 3:  Loss_train:     0.0053 Accuracy_train: 1.000000 Loss_valid:     1.4341 Accuracy_valid: 0.742800
# Epoch 70, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.3522 Accuracy_valid: 0.744600
# Epoch 70, CIFAR-10 Batch 5:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4385 Accuracy_valid: 0.739800
# Epoch 71, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4405 Accuracy_valid: 0.729200
# Epoch 71, CIFAR-10 Batch 2:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.4273 Accuracy_valid: 0.734000
# Epoch 71, CIFAR-10 Batch 3:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4312 Accuracy_valid: 0.746800
# Epoch 71, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4587 Accuracy_valid: 0.731800
# Epoch 71, CIFAR-10 Batch 5:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3845 Accuracy_valid: 0.735000
# Epoch 72, CIFAR-10 Batch 1:  Loss_train:     0.0009 Accuracy_train: 1.000000 Loss_valid:     1.4099 Accuracy_valid: 0.740600
# Epoch 72, CIFAR-10 Batch 2:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4532 Accuracy_valid: 0.737200
# Epoch 72, CIFAR-10 Batch 3:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.5118 Accuracy_valid: 0.740400
# Epoch 72, CIFAR-10 Batch 4:  Loss_train:     0.0046 Accuracy_train: 1.000000 Loss_valid:     1.5241 Accuracy_valid: 0.733600
# Epoch 72, CIFAR-10 Batch 5:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4416 Accuracy_valid: 0.741000
# Epoch 73, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4266 Accuracy_valid: 0.742800
# Epoch 73, CIFAR-10 Batch 2:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4566 Accuracy_valid: 0.738400
# Epoch 73, CIFAR-10 Batch 3:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4083 Accuracy_valid: 0.742200
# Epoch 73, CIFAR-10 Batch 4:  Loss_train:     0.0022 Accuracy_train: 1.000000 Loss_valid:     1.4677 Accuracy_valid: 0.736800
# Epoch 73, CIFAR-10 Batch 5:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4417 Accuracy_valid: 0.742800
# Epoch 74, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4303 Accuracy_valid: 0.738000
# Epoch 74, CIFAR-10 Batch 2:  Loss_train:     0.0009 Accuracy_train: 1.000000 Loss_valid:     1.3757 Accuracy_valid: 0.744600
# Epoch 74, CIFAR-10 Batch 3:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.4262 Accuracy_valid: 0.747000
# Epoch 74, CIFAR-10 Batch 4:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.4981 Accuracy_valid: 0.728600
# Epoch 74, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4497 Accuracy_valid: 0.747200
# Epoch 75, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4404 Accuracy_valid: 0.738400
# Epoch 75, CIFAR-10 Batch 2:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4101 Accuracy_valid: 0.744800
# Epoch 75, CIFAR-10 Batch 3:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.4333 Accuracy_valid: 0.743200
# Epoch 75, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4362 Accuracy_valid: 0.743800
# Epoch 75, CIFAR-10 Batch 5:  Loss_train:     0.0028 Accuracy_train: 1.000000 Loss_valid:     1.3775 Accuracy_valid: 0.740400
# Epoch 76, CIFAR-10 Batch 1:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4696 Accuracy_valid: 0.734600
# Epoch 76, CIFAR-10 Batch 2:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4879 Accuracy_valid: 0.733000
# Epoch 76, CIFAR-10 Batch 3:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4218 Accuracy_valid: 0.747800
# Epoch 76, CIFAR-10 Batch 4:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.4229 Accuracy_valid: 0.740600
# Epoch 76, CIFAR-10 Batch 5:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.4882 Accuracy_valid: 0.741200
# Epoch 77, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5108 Accuracy_valid: 0.740400
# Epoch 77, CIFAR-10 Batch 2:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4788 Accuracy_valid: 0.740000
# Epoch 77, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.4357 Accuracy_valid: 0.740600
# Epoch 77, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4148 Accuracy_valid: 0.737400
# Epoch 77, CIFAR-10 Batch 5:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.4196 Accuracy_valid: 0.740400
# Epoch 78, CIFAR-10 Batch 1:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4985 Accuracy_valid: 0.733000
# Epoch 78, CIFAR-10 Batch 2:  Loss_train:     0.0051 Accuracy_train: 1.000000 Loss_valid:     1.5197 Accuracy_valid: 0.735600
# Epoch 78, CIFAR-10 Batch 3:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.4593 Accuracy_valid: 0.738800
# Epoch 78, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4402 Accuracy_valid: 0.740800
# Epoch 78, CIFAR-10 Batch 5:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4409 Accuracy_valid: 0.739600
# Epoch 79, CIFAR-10 Batch 1:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.5354 Accuracy_valid: 0.741000
# Epoch 79, CIFAR-10 Batch 2:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.4978 Accuracy_valid: 0.745000
# Epoch 79, CIFAR-10 Batch 3:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.6123 Accuracy_valid: 0.736200
# Epoch 79, CIFAR-10 Batch 4:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.4457 Accuracy_valid: 0.737600
# Epoch 79, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4412 Accuracy_valid: 0.739800
# Epoch 80, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4376 Accuracy_valid: 0.741800
# Epoch 80, CIFAR-10 Batch 2:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.4545 Accuracy_valid: 0.740800
# Epoch 80, CIFAR-10 Batch 3:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.3905 Accuracy_valid: 0.746800
# Epoch 80, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4018 Accuracy_valid: 0.745800
# Epoch 80, CIFAR-10 Batch 5:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4278 Accuracy_valid: 0.742400
# Epoch 81, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4813 Accuracy_valid: 0.738800
# Epoch 81, CIFAR-10 Batch 2:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.4987 Accuracy_valid: 0.734600
# Epoch 81, CIFAR-10 Batch 3:  Loss_train:     0.0028 Accuracy_train: 1.000000 Loss_valid:     1.5281 Accuracy_valid: 0.740000
# Epoch 81, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4458 Accuracy_valid: 0.741000
# Epoch 81, CIFAR-10 Batch 5:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5263 Accuracy_valid: 0.728400
# Epoch 82, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4507 Accuracy_valid: 0.744200
# Epoch 82, CIFAR-10 Batch 2:  Loss_train:     0.0009 Accuracy_train: 1.000000 Loss_valid:     1.4497 Accuracy_valid: 0.745000
# Epoch 82, CIFAR-10 Batch 3:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5256 Accuracy_valid: 0.743600
# Epoch 82, CIFAR-10 Batch 4:  Loss_train:     0.0010 Accuracy_train: 1.000000 Loss_valid:     1.4224 Accuracy_valid: 0.738800
# Epoch 82, CIFAR-10 Batch 5:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.3738 Accuracy_valid: 0.745800
# Epoch 83, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4741 Accuracy_valid: 0.739000
# Epoch 83, CIFAR-10 Batch 2:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.3840 Accuracy_valid: 0.744800
# Epoch 83, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4596 Accuracy_valid: 0.747200
# Epoch 83, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4106 Accuracy_valid: 0.745600
# Epoch 83, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4293 Accuracy_valid: 0.734000
# Epoch 84, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4368 Accuracy_valid: 0.750200
# Epoch 84, CIFAR-10 Batch 2:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4369 Accuracy_valid: 0.745200
# Epoch 84, CIFAR-10 Batch 3:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.4528 Accuracy_valid: 0.747200
# Epoch 84, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4560 Accuracy_valid: 0.739200
# Epoch 84, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4288 Accuracy_valid: 0.737400
# Epoch 85, CIFAR-10 Batch 1:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4008 Accuracy_valid: 0.739600
# Epoch 85, CIFAR-10 Batch 2:  Loss_train:     0.0118 Accuracy_train: 1.000000 Loss_valid:     1.4436 Accuracy_valid: 0.735600
# Epoch 85, CIFAR-10 Batch 3:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.3957 Accuracy_valid: 0.740200
# Epoch 85, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.3948 Accuracy_valid: 0.736200
# Epoch 85, CIFAR-10 Batch 5:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4677 Accuracy_valid: 0.732600
# Epoch 86, CIFAR-10 Batch 1:  Loss_train:     0.0013 Accuracy_train: 1.000000 Loss_valid:     1.4496 Accuracy_valid: 0.736200
# Epoch 86, CIFAR-10 Batch 2:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4384 Accuracy_valid: 0.740000
# Epoch 86, CIFAR-10 Batch 3:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4526 Accuracy_valid: 0.738200
# Epoch 86, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4527 Accuracy_valid: 0.740400
# Epoch 86, CIFAR-10 Batch 5:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4923 Accuracy_valid: 0.739600
# Epoch 87, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4364 Accuracy_valid: 0.739600
# Epoch 87, CIFAR-10 Batch 2:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.5082 Accuracy_valid: 0.732000
# Epoch 87, CIFAR-10 Batch 3:  Loss_train:     0.0011 Accuracy_train: 1.000000 Loss_valid:     1.4724 Accuracy_valid: 0.741000
# Epoch 87, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4967 Accuracy_valid: 0.743400
# Epoch 87, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5561 Accuracy_valid: 0.729200
# Epoch 88, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.6038 Accuracy_valid: 0.730800
# Epoch 88, CIFAR-10 Batch 2:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4554 Accuracy_valid: 0.739400
# Epoch 88, CIFAR-10 Batch 3:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4498 Accuracy_valid: 0.740800
# Epoch 88, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4127 Accuracy_valid: 0.739800
# Epoch 88, CIFAR-10 Batch 5:  Loss_train:     0.0016 Accuracy_train: 1.000000 Loss_valid:     1.4614 Accuracy_valid: 0.736600
# Epoch 89, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4704 Accuracy_valid: 0.741200
# Epoch 89, CIFAR-10 Batch 2:  Loss_train:     0.0018 Accuracy_train: 1.000000 Loss_valid:     1.4346 Accuracy_valid: 0.738600
# Epoch 89, CIFAR-10 Batch 3:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4619 Accuracy_valid: 0.739000
# Epoch 89, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4470 Accuracy_valid: 0.735600
# Epoch 89, CIFAR-10 Batch 5:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4149 Accuracy_valid: 0.744400
# Epoch 90, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4785 Accuracy_valid: 0.742800
# Epoch 90, CIFAR-10 Batch 2:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4534 Accuracy_valid: 0.744000
# Epoch 90, CIFAR-10 Batch 3:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4838 Accuracy_valid: 0.747400
# Epoch 90, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.4803 Accuracy_valid: 0.737600
# Epoch 90, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4548 Accuracy_valid: 0.743200
# Epoch 91, CIFAR-10 Batch 1:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4759 Accuracy_valid: 0.748000
# Epoch 91, CIFAR-10 Batch 2:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4354 Accuracy_valid: 0.740800
# Epoch 91, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4429 Accuracy_valid: 0.747200
# Epoch 91, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4684 Accuracy_valid: 0.737600
# Epoch 91, CIFAR-10 Batch 5:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5072 Accuracy_valid: 0.739000
# Epoch 92, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5313 Accuracy_valid: 0.748600
# Epoch 92, CIFAR-10 Batch 2:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4707 Accuracy_valid: 0.739800
# Epoch 92, CIFAR-10 Batch 3:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5189 Accuracy_valid: 0.740200
# Epoch 92, CIFAR-10 Batch 4:  Loss_train:     0.0007 Accuracy_train: 1.000000 Loss_valid:     1.5471 Accuracy_valid: 0.737400
# Epoch 92, CIFAR-10 Batch 5:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4445 Accuracy_valid: 0.747600
# Epoch 93, CIFAR-10 Batch 1:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     1.5005 Accuracy_valid: 0.748000
# Epoch 93, CIFAR-10 Batch 2:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.5100 Accuracy_valid: 0.735200
# Epoch 93, CIFAR-10 Batch 3:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4113 Accuracy_valid: 0.753600
# Epoch 93, CIFAR-10 Batch 4:  Loss_train:     0.0005 Accuracy_train: 1.000000 Loss_valid:     1.4537 Accuracy_valid: 0.741000
# Epoch 93, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4910 Accuracy_valid: 0.738800
# Epoch 94, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4266 Accuracy_valid: 0.744800
# Epoch 94, CIFAR-10 Batch 2:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4146 Accuracy_valid: 0.750400
# Epoch 94, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.4164 Accuracy_valid: 0.751000
# Epoch 94, CIFAR-10 Batch 4:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.6016 Accuracy_valid: 0.737600
# Epoch 94, CIFAR-10 Batch 5:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.5391 Accuracy_valid: 0.734400
# Epoch 95, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4701 Accuracy_valid: 0.740200
# Epoch 95, CIFAR-10 Batch 2:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5076 Accuracy_valid: 0.737600
# Epoch 95, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4174 Accuracy_valid: 0.748000
# Epoch 95, CIFAR-10 Batch 4:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.5257 Accuracy_valid: 0.735800
# Epoch 95, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4671 Accuracy_valid: 0.747000
# Epoch 96, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4641 Accuracy_valid: 0.752000
# Epoch 96, CIFAR-10 Batch 2:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4532 Accuracy_valid: 0.745600
# Epoch 96, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4065 Accuracy_valid: 0.752200
# Epoch 96, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5088 Accuracy_valid: 0.736600
# Epoch 96, CIFAR-10 Batch 5:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4836 Accuracy_valid: 0.738800
# Epoch 97, CIFAR-10 Batch 1:  Loss_train:     0.0006 Accuracy_train: 1.000000 Loss_valid:     1.4735 Accuracy_valid: 0.753800
# Epoch 97, CIFAR-10 Batch 2:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4165 Accuracy_valid: 0.743000
# Epoch 97, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4512 Accuracy_valid: 0.752400
# Epoch 97, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5386 Accuracy_valid: 0.739200
# Epoch 97, CIFAR-10 Batch 5:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.5573 Accuracy_valid: 0.739000
# Epoch 98, CIFAR-10 Batch 1:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5976 Accuracy_valid: 0.744800
# Epoch 98, CIFAR-10 Batch 2:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.5349 Accuracy_valid: 0.740600
# Epoch 98, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4525 Accuracy_valid: 0.744000
# Epoch 98, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5183 Accuracy_valid: 0.742000
# Epoch 98, CIFAR-10 Batch 5:  Loss_train:     0.0003 Accuracy_train: 1.000000 Loss_valid:     1.5859 Accuracy_valid: 0.739600
# Epoch 99, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5706 Accuracy_valid: 0.744600
# Epoch 99, CIFAR-10 Batch 2:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.5262 Accuracy_valid: 0.743800
# Epoch 99, CIFAR-10 Batch 3:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.4758 Accuracy_valid: 0.748400
# Epoch 99, CIFAR-10 Batch 4:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5044 Accuracy_valid: 0.739400
# Epoch 99, CIFAR-10 Batch 5:  Loss_train:     0.0008 Accuracy_train: 1.000000 Loss_valid:     1.4436 Accuracy_valid: 0.743400
# Epoch 100, CIFAR-10 Batch 1:  Loss_train:     0.0001 Accuracy_train: 1.000000 Loss_valid:     1.5041 Accuracy_valid: 0.750400
# Epoch 100, CIFAR-10 Batch 2:  Loss_train:     0.0000 Accuracy_train: 1.000000 Loss_valid:     1.4967 Accuracy_valid: 0.741600
# Epoch 100, CIFAR-10 Batch 3:  Loss_train:     0.0004 Accuracy_train: 1.000000 Loss_valid:     1.4979 Accuracy_valid: 0.740800
# Epoch 100, CIFAR-10 Batch 4:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4962 Accuracy_valid: 0.733400
# Epoch 100, CIFAR-10 Batch 5:  Loss_train:     0.0002 Accuracy_train: 1.000000 Loss_valid:     1.4669 Accuracy_valid: 0.746000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7359375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
