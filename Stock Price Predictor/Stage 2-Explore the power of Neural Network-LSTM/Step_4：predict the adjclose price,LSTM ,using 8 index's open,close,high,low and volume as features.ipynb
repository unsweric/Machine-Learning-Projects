# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
data_open_SP500=pd.read_csv('SP500_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_SP500=pd.read_csv('SP500_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_SP500=pd.read_csv('SP500_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_SP500=pd.read_csv('SP500_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_SP500=pd.read_csv('SP500_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_SP500=pd.read_csv('SP500_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_Nasdaq=pd.read_csv('Nasdaq_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_Nasdaq=pd.read_csv('Nasdaq_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_Nasdaq=pd.read_csv('Nasdaq_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_Nasdaq=pd.read_csv('Nasdaq_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_Nasdaq=pd.read_csv('Nasdaq_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_Nasdaq=pd.read_csv('Nasdaq_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_DJI=pd.read_csv('DJI_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_DJI=pd.read_csv('DJI_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_DJI=pd.read_csv('DJI_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_DJI=pd.read_csv('DJI_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_DJI=pd.read_csv('DJI_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_DJI=pd.read_csv('DJI_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_DAX=pd.read_csv('DAX_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_DAX=pd.read_csv('DAX_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_DAX=pd.read_csv('DAX_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_DAX=pd.read_csv('DAX_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_DAX=pd.read_csv('DAX_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_DAX=pd.read_csv('DAX_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_Paris=pd.read_csv('Paris_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_Paris=pd.read_csv('Paris_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_Paris=pd.read_csv('Paris_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_Paris=pd.read_csv('Paris_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_Paris=pd.read_csv('Paris_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_Paris=pd.read_csv('Paris_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_Tokyo=pd.read_csv('Tokyo_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_Tokyo=pd.read_csv('Tokyo_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_Tokyo=pd.read_csv('Tokyo_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_Tokyo=pd.read_csv('Tokyo_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_Tokyo=pd.read_csv('Tokyo_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_Tokyo=pd.read_csv('Tokyo_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_HongKong=pd.read_csv('HongKong_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_HongKong=pd.read_csv('HongKong_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_HongKong=pd.read_csv('HongKong_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_HongKong=pd.read_csv('HongKong_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_HongKong=pd.read_csv('HongKong_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_HongKong=pd.read_csv('HongKong_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

data_open_Aus=pd.read_csv('Aus_new.csv', usecols=[1],engine='python', skipfooter=1).values.astype('float32')
data_high_Aus=pd.read_csv('Aus_new.csv', usecols=[2],engine='python', skipfooter=1).values.astype('float32')
data_low_Aus=pd.read_csv('Aus_new.csv', usecols=[3],engine='python', skipfooter=1).values.astype('float32')
data_close_Aus=pd.read_csv('Aus_new.csv', usecols=[4],engine='python', skipfooter=1).values.astype('float32')
data_adjclose_Aus=pd.read_csv('Aus_new.csv', usecols=[5],engine='python', skipfooter=1).values.astype('float32')
data_vloume_Aus=pd.read_csv('Aus_new.csv', usecols=[6],engine='python', skipfooter=1).values.astype('float32')

# %%
dataX = []
for i in range(len(data_open_SP500)):
    a=[]
    
    a.append(data_open_SP500[i, 0])
    a.append(data_high_SP500[i, 0])
    a.append(data_low_SP500[i, 0])
    a.append(data_close_SP500[i, 0])
    a.append(data_adjclose_SP500[i, 0])
    a.append(data_vloume_SP500[i, 0])
    
    a.append(data_open_Nasdaq[i, 0])
    a.append(data_high_Nasdaq[i, 0])
    a.append(data_low_Nasdaq[i, 0])
    a.append(data_close_Nasdaq[i, 0])
    a.append(data_adjclose_Nasdaq[i, 0])
    a.append(data_vloume_Nasdaq[i, 0])
    
    a.append(data_open_DJI[i, 0])
    a.append(data_high_DJI[i, 0])
    a.append(data_low_DJI[i, 0])
    a.append(data_close_DJI[i, 0])
    a.append(data_adjclose_DJI[i, 0])
    a.append(data_vloume_DJI[i, 0])
    
    a.append(data_open_DAX[i, 0])
    a.append(data_high_DAX[i, 0])
    a.append(data_low_DAX[i, 0])
    a.append(data_close_DAX[i, 0])
    a.append(data_adjclose_DAX[i, 0])
    #a.append(data_vloume_DAX[i, 0])
    
    a.append(data_open_Paris[i, 0])
    a.append(data_high_Paris[i, 0])
    a.append(data_low_Paris[i, 0])
    a.append(data_close_Paris[i, 0])
    a.append(data_adjclose_Paris[i, 0])
    #a.append(data_vloume_Paris[i, 0])
    
    a.append(data_open_Tokyo[i, 0])
    a.append(data_high_Tokyo[i, 0])
    a.append(data_low_Tokyo[i, 0])
    a.append(data_close_Tokyo[i, 0])
    a.append(data_adjclose_Tokyo[i, 0])
    #a.append(data_vloume_Tokyo[i, 0])
    
    a.append(data_open_HongKong[i, 0])
    a.append(data_high_HongKong[i, 0])
    a.append(data_low_HongKong[i, 0])
    a.append(data_close_HongKong[i, 0])
    a.append(data_adjclose_HongKong[i, 0])
    #a.append(data_vloume_HongKong[i, 0])
    
    a.append(data_open_Aus[i, 0])
    a.append(data_high_Aus[i, 0])
    a.append(data_low_Aus[i, 0])
    a.append(data_close_Aus[i, 0])
    a.append(data_adjclose_Aus[i, 0])
    #a.append(data_vloume_Aus[i, 0])
    dataX.append(a)
dataset=numpy.array(dataX)

# %%
len(dataset[0])
# Out:
# 43

# %%
dataY = []
for i in range(1,len(data_open_SP500)):
    a=[]
    a.append(data_adjclose_SP500[i, 0])
    dataY.append(a)
target=numpy.array(dataY)

# %%
dataset=dataset[:-1]

# %%
len(dataset)
len(target)
# Out:
# 5030

# %%
# normalize the dataset
scaler_dataset = MinMaxScaler(feature_range=(0, 1))
dataset = scaler_dataset.fit_transform(dataset)

# %%
# normalize the dataset
scaler_target = MinMaxScaler(feature_range=(0, 1))
target = scaler_target.fit_transform(target)

# %%
trainX=dataset[:-500]
testX=dataset[-500:]
trainY=target[:-500]
testY=target[-500:]

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# 1，epochs=500

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1,len(dataset[0]))))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=500, batch_size=1, verbose=2)
# Out:
# Epoch 1/500
# 9s - loss: 0.0016
# Epoch 2/500
# 8s - loss: 2.4372e-04
# Epoch 3/500
# 7s - loss: 1.7664e-04
# Epoch 4/500
# 7s - loss: 1.5792e-04
# Epoch 5/500
# 7s - loss: 1.4882e-04
# Epoch 6/500
# 7s - loss: 1.4405e-04
# Epoch 7/500
# 7s - loss: 1.4046e-04
# Epoch 8/500
# 7s - loss: 1.2627e-04
# Epoch 9/500
# 7s - loss: 1.3012e-04
# Epoch 10/500
# 7s - loss: 1.2097e-04
# Epoch 11/500
# 8s - loss: 1.1937e-04
# Epoch 12/500
# 9s - loss: 1.2089e-04
# Epoch 13/500
# 8s - loss: 1.1666e-04
# Epoch 14/500
# 8s - loss: 1.1407e-04
# Epoch 15/500
# 8s - loss: 1.1312e-04
# Epoch 16/500
# 9s - loss: 1.1068e-04
# Epoch 17/500
# 7s - loss: 1.0928e-04
# Epoch 18/500
# 5s - loss: 1.0584e-04
# Epoch 19/500
# 5s - loss: 1.0732e-04
# Epoch 20/500
# 5s - loss: 1.0340e-04
# Epoch 21/500
# 5s - loss: 1.0642e-04
# Epoch 22/500
# 5s - loss: 1.0564e-04
# Epoch 23/500
# 5s - loss: 1.0417e-04
# Epoch 24/500
# 5s - loss: 1.0135e-04
# Epoch 25/500
# 5s - loss: 1.0447e-04
# Epoch 26/500
# ...

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict =  scaler_target.inverse_transform(trainPredict)
trainY =  scaler_target.inverse_transform(trainY)
testPredict =  scaler_target.inverse_transform(testPredict)
testY =  scaler_target.inverse_transform(testY)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))

from sklearn.metrics import r2_score
print(r2_score(testY, testPredict))

test_true=testY[:200]
test_pred=testPredict[:200]

fig, ax = plt.subplots(figsize=(100, 50))
plt.plot(test_true,color='red')
plt.plot(test_pred,color='blue')
plt.show()


test_true=testY[:29]
test_pred=testPredict[:29]

test_true_clssfi=[]
for  i in range(1,len(test_true)):
    if test_true[i]>test_true[i-1]:
        test_true_clssfi.append(1)
    else:
        test_true_clssfi.append(0)
        
test_pred_clssfi=[]
for  i in range(1,len(test_pred)):
    if test_pred[i]>test_true[i-1]:
        test_pred_clssfi.append(1)
    else:
        test_pred_clssfi.append(0)
        
from sklearn.metrics import accuracy_score
result = accuracy_score(test_true_clssfi,test_pred_clssfi)
print(result)
# Out:
# Train Score: 15.97 RMSE
# Test Score: 137.20 RMSE
# 0.149531498906
# 0.535714285714

# %% [markdown]
# 2，two  layres,10 neurons,epochs=1000

# %%
import time
start = time.time()


# create and fit the LSTM network
model = Sequential()
model.add(LSTM(10, input_shape=(1,len(dataset[0])),return_sequences=True))
model.add(LSTM(10, input_shape=(1,len(dataset[0]))))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=1000, batch_size=1, verbose=2)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict =  scaler_target.inverse_transform(trainPredict)
trainY =  scaler_target.inverse_transform(trainY)
testPredict =  scaler_target.inverse_transform(testPredict)
testY =  scaler_target.inverse_transform(testY)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))

from sklearn.metrics import r2_score
print(r2_score(testY, testPredict))

test_true=testY[:200]
test_pred=testPredict[:200]

fig, ax = plt.subplots(figsize=(100, 50))
plt.plot(test_true,color='red')
plt.plot(test_pred,color='blue')
plt.show()


test_true=testY[:29]
test_pred=testPredict[:29]

test_true_clssfi=[]
for  i in range(1,len(test_true)):
    if test_true[i]>test_true[i-1]:
        test_true_clssfi.append(1)
    else:
        test_true_clssfi.append(0)
        
test_pred_clssfi=[]
for  i in range(1,len(test_pred)):
    if test_pred[i]>test_true[i-1]:
        test_pred_clssfi.append(1)
    else:
        test_pred_clssfi.append(0)
        
from sklearn.metrics import accuracy_score
result = accuracy_score(test_true_clssfi,test_pred_clssfi)
print(result)


print( time.time() - start)
# Out:
# Epoch 1/1000
# 16s - loss: 0.0014
# Epoch 2/1000
# 14s - loss: 2.1313e-04
# Epoch 3/1000
# 14s - loss: 1.9216e-04
# Epoch 4/1000
# 15s - loss: 1.5831e-04
# Epoch 5/1000
# 13s - loss: 1.6185e-04
# Epoch 6/1000
# 13s - loss: 1.4703e-04
# Epoch 7/1000
# 13s - loss: 1.4487e-04
# Epoch 8/1000
# 13s - loss: 1.3884e-04
# Epoch 9/1000
# 13s - loss: 1.4295e-04
# Epoch 10/1000
# 13s - loss: 1.2825e-04
# Epoch 11/1000
# 13s - loss: 1.2603e-04
# Epoch 12/1000
# 13s - loss: 1.3685e-04
# Epoch 13/1000
# 13s - loss: 1.2874e-04
# Epoch 14/1000
# 13s - loss: 1.2343e-04
# Epoch 15/1000
# 14s - loss: 1.2767e-04
# Epoch 16/1000
# 14s - loss: 1.2677e-04
# Epoch 17/1000
# 14s - loss: 1.2358e-04
# Epoch 18/1000
# 13s - loss: 1.2585e-04
# Epoch 19/1000
# 13s - loss: 1.2443e-04
# Epoch 20/1000
# 14s - loss: 1.2440e-04
# Epoch 21/1000
# 13s - loss: 1.1356e-04
# Epoch 22/1000
# 14s - loss: 1.1647e-04
# Epoch 23/1000
# 13s - loss: 1.1786e-04
# Epoch 24/1000
# 14s - loss: 1.1356e-04
# Epoch 25/1000
# ...

# %% [markdown]
# 3，two layres,4 neurons,epochs=1000

# %%
import time
start = time.time()


# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1,len(dataset[0])),return_sequences=True))
model.add(LSTM(4, input_shape=(1,len(dataset[0]))))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=1000, batch_size=1, verbose=2)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict =  scaler_target.inverse_transform(trainPredict)
trainY =  scaler_target.inverse_transform(trainY)
testPredict =  scaler_target.inverse_transform(testPredict)
testY =  scaler_target.inverse_transform(testY)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))

from sklearn.metrics import r2_score
print(r2_score(testY, testPredict))

test_true=testY[:200]
test_pred=testPredict[:200]

fig, ax = plt.subplots(figsize=(100, 50))
plt.plot(test_true,color='red')
plt.plot(test_pred,color='blue')
plt.show()


test_true=testY[:29]
test_pred=testPredict[:29]

test_true_clssfi=[]
for  i in range(1,len(test_true)):
    if test_true[i]>test_true[i-1]:
        test_true_clssfi.append(1)
    else:
        test_true_clssfi.append(0)
        
test_pred_clssfi=[]
for  i in range(1,len(test_pred)):
    if test_pred[i]>test_true[i-1]:
        test_pred_clssfi.append(1)
    else:
        test_pred_clssfi.append(0)
        
from sklearn.metrics import accuracy_score
result = accuracy_score(test_true_clssfi,test_pred_clssfi)
print(result)


print( time.time() - start)
# Out:
# Epoch 1/1000
# 11s - loss: 0.0025
# Epoch 2/1000
# 10s - loss: 2.1697e-04
# Epoch 3/1000
# 10s - loss: 1.7764e-04
# Epoch 4/1000
# 10s - loss: 1.5706e-04
# Epoch 5/1000
# 10s - loss: 1.4135e-04
# Epoch 6/1000
# 10s - loss: 1.3434e-04
# Epoch 7/1000
# 10s - loss: 1.3973e-04
# Epoch 8/1000
# 10s - loss: 1.2986e-04
# Epoch 9/1000
# 10s - loss: 1.2739e-04
# Epoch 10/1000
# 10s - loss: 1.2233e-04
# Epoch 11/1000
# 10s - loss: 1.2558e-04
# Epoch 12/1000
# 10s - loss: 1.2487e-04
# Epoch 13/1000
# 10s - loss: 1.2150e-04
# Epoch 14/1000
# 10s - loss: 1.2346e-04
# Epoch 15/1000
# 10s - loss: 1.2027e-04
# Epoch 16/1000
# 10s - loss: 1.2022e-04
# Epoch 17/1000
# 10s - loss: 1.1794e-04
# Epoch 18/1000
# 10s - loss: 1.1816e-04
# Epoch 19/1000
# 10s - loss: 1.1962e-04
# Epoch 20/1000
# 10s - loss: 1.1215e-04
# Epoch 21/1000
# 10s - loss: 1.1515e-04
# Epoch 22/1000
# 10s - loss: 1.1825e-04
# Epoch 23/1000
# 10s - loss: 1.1754e-04
# Epoch 24/1000
# 10s - loss: 1.1034e-04
# Epoch 25/1000
# ...
